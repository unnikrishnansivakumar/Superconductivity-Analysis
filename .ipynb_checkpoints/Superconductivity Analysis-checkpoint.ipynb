# %% [markdown]
# ### 1. Loading Data

# %%
supercon_data <- read.csv('dataset/train.csv')

# %%
head(supercon_data,5)
# Out:
#   number_of_elements mean_atomic_mass wtd_mean_atomic_mass gmean_atomic_mass
# 1 4                  88.94447         57.86269             66.36159
# 2 5                  92.72921         58.51842             73.13279
# 3 4                  88.94447         57.88524             66.36159
# 4 4                  88.94447         57.87397             66.36159
# 5 4                  88.94447         57.84014             66.36159
#   wtd_gmean_atomic_mass entropy_atomic_mass wtd_entropy_atomic_mass
# 1 36.11661              1.181795            1.0623955
# 2 36.39660              1.449309            1.0577551
# 3 36.12251              1.181795            0.9759805
# 4 36.11956              1.181795            1.0222909
# 5 36.11072              1.181795            1.1292237
#   range_atomic_mass wtd_range_atomic_mass std_atomic_mass ... wtd_mean_Valence
# 1 122.9061          31.79492              51.96883        ... 2.257143
# 2 122.9061          36.16194              47.09463        ... 2.257143
# 3 122.9061          35.74110              51.96883        ... 2.271429
# 4 122.9061          33.76801              51.96883        ... 2.264286
# 5 122.9061          27.84874              51.96883        ... 2.242857
#   gmean_Valence wtd_gmean_Valence entropy_Valence wtd_entropy_Valence
# 1 2.213364      2.219783          1.368922        1.066221
# 2 1.888175      2.210679          1.557113        1.047221
# 3 2.213364      2.232679          1.368922        1.029175
# 4 2.213364      2.226222          1.368922        1.048834
# 5 2.213364      2.206963          1.368922        1.096052
#   range_Valence wtd_range_Valence std_Valence wtd_std_Valence critical_temp
# 1 1             1.085714          0.4330127   0.4370588       29
# 2 2             1.128571          0.6324555   0.4686063       26
# 3 1             1.114286          0.4330127   0.4446966       19
# 4 1             1.100000          0.4330127   0.4409521       22
# 5 1             1.057143          0.4330127   0.4288095       23

# %% [markdown]
# ### 2. Data Cleaning

# %% [markdown]
# 2.1.1. Leverages, Outliers and Influence

# %%
lev_fit = lm(critical_temp ~ ., data = supercon_data)
# Use function "hatvalues" for the leverages from the lm object
leverages = hatvalues(lev_fit)
max_i = which.max(leverages)

# %%
par(mfrow=c(1,2))
plot(fitted(lev_fit), resid(lev_fit), col = "grey", pch = 20,
     xlab = "Fitted", ylab = "Residual",cex=2,
     main = "Fitted versus Residuals")
abline(h = 0, col = "darkorange", lwd = 2)
# Out:
# Plot with title "Fitted versus Residuals"

# %%
qqnorm(resid(lev_fit), col = "grey",pch=20,cex=2)
qqline(resid(lev_fit), col = "dodgerblue", lwd = 2)
# Out:
# Plot with title "Normal Q-Q Plot"

# %%
lev_fit_cd = cooks.distance(lev_fit)

# %%
sum(lev_fit_cd > 4/length(lev_fit_cd))
# Out:
# [1] 792

# %%
inf_i = which(lev_fit_cd > 4/length(lev_fit_cd))
supercon_data_ou_tr = supercon_data[-inf_i,]

# %%
lev_fit_2 = lm(critical_temp ~ ., data = supercon_data_ou_tr)

# %%
par(mfrow=c(1,2))
plot(fitted(lev_fit_2), resid(lev_fit_2), col = "grey", pch = 20,
     xlab = "Fitted", ylab = "Residual",cex=2,
     main = "Fitted versus Residuals")
abline(h = 0, col = "darkorange", lwd = 2)
# Out:
# Plot with title "Fitted versus Residuals"

# %%
qqnorm(resid(lev_fit_2), col = "grey",pch=20,cex=2)
qqline(resid(lev_fit_2), col = "dodgerblue", lwd = 2)
# Out:
# Plot with title "Normal Q-Q Plot"

# %%
qqnorm(resid(lm_disp_wt2), col = "grey",pch=20,cex=2)
qqline(resid(lm_disp_wt2), col = "dodgerblue", lwd = 2)

# %% [markdown]
# Removing High leverage points has improved the residual and normality assumptions

# %% [markdown]
# ### 3. Correlation Analysis

# %%
library(corrplot)

# %%
library(dplyr)
library(caret)

# %%
# Correlation plot - High Correlation among variables
# It can be seen that high correlation exists!
correlations <- cor(supercon_data)
corrplot(correlations, method="circle",tl.cex=0.5)

# %%
cor_matrix = cor(supercon_data)
cor_matrix[1:5,1:5] #glimpse of the correlation matrix created

# %%
drop = findCorrelation(cor_matrix, cutoff = .6)
drop = names(supercon_data)[drop]
supercon_data_corr_rem = supercon_data[ , !(names(supercon_data) %in% drop)]

# %%
correlations <- cor(supercon_data_corr_rem)
corrplot(correlations, method="circle",tl.cex=0.5)

# %%
#Getting the highly correlated variable groups for better explainability
row_col_mat = which(cor_matrix>=0.6, arr.ind=TRUE)
rc_df = as.data.frame(row_col_mat)
correlated_var_groups = rc_df %>% group_by(row) %>% 
summarize(col = paste(sort(unique(col)),collapse=", "))

# %% [markdown]
# ### First Cut Model Creation

# %%
model<-lm(critical_temp~.,data=supercon_data_corr_rem)
summary(model)

# %% [markdown]
# ### 3. AIC/BIC Methods

# %%
#construct full model
model_full = lm(critical_temp~.,data=supercon_data)

# %%
fit_back_aic = step(model_full, direction = "backward")
fit_back_aic
# Out:
# Start:  AIC=122021.5
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     wtd_entropy_atomic_mass + range_atomic_mass + wtd_range_atomic_mass +
#     std_atomic_mass + wtd_std_atomic_mass + mean_fie + wtd_mean_fie +
#     gmean_fie + wtd_gmean_fie + entropy_fie + wtd_entropy_fie +
#     range_fie + wtd_range_fie + std_fie + wtd_std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + gmean_atomic_radius + wtd_gmean_atomic_radius +
#     entropy_atomic_radius + wtd_entropy_atomic_radius + range_atomic_radius +
#     wtd_range_atomic_radius + std_atomic_radius + wtd_std_atomic_radius +
#     mean_Density + wtd_mean_Density + gmean_Density + wtd_gmean_Density +
#     entropy_Density + wtd_entropy_Density + range_Density + wtd_range_Density +
#     std_Density + wtd_std_Density + mean_ElectronAffinity + wtd_mean_ElectronAffinity +
#     gmean_ElectronAffinity + wtd_gmean_ElectronAffinity + entropy_ElectronAffinity +
#     wtd_entropy_ElectronAffinity + range_ElectronAffinity + wtd_range_ElectronAffinity +
#     std_ElectronAffinity + wtd_std_ElectronAffinity + mean_FusionHeat +
#     wtd_mean_FusionHeat + gmean_FusionHeat + wtd_gmean_FusionHeat +
#     entropy_FusionHeat + wtd_entropy_FusionHeat + range_FusionHeat +
#     wtd_range_FusionHeat + std_FusionHeat + wtd_std_FusionHeat +
#     mean_ThermalConductivity + wtd_mean_ThermalConductivity +
#     gmean_ThermalConductivity + wtd_gmean_ThermalConductivity +
#     entropy_ThermalConductivity + wtd_entropy_ThermalConductivity +
#     range_ThermalConductivity + wtd_range_ThermalConductivity +
#     std_ThermalConductivity + wtd_std_ThermalConductivity + mean_Valence +
#     wtd_mean_Valence + gmean_Valence + wtd_gmean_Valence + entropy_Valence +
#     wtd_entropy_Valence + range_Valence + wtd_range_Valence +
#     std_Valence + wtd_std_Valence
#
#                                   Df Sum of Sq     RSS    AIC
# - wtd_range_Density                1        12 6554671 122020
# - wtd_mean_Density                 1        22 6554681 122020
# - wtd_std_ThermalConductivity      1        36 6554695 122020
# - wtd_entropy_ThermalConductivity  1       266 6554925 122020
# - gmean_atomic_radius              1       385 6555044 122021
# - wtd_std_fie                      1       393 6555052 122021
# - wtd_range_atomic_mass            1       429 6555088 122021
# - wtd_range_Valence                1       477 6555135 122021
# - wtd_entropy_atomic_mass          1       485 6555144 122021
# <none>                                         6554659 122021
# - wtd_std_atomic_mass              1       848 6555507 122022
# - entropy_ElectronAffinity         1       930 6555589 122022
# - std_FusionHeat                   1      1416 6556075 122024
# - wtd_mean_fie                     1      1653 6556312 122025
# - mean_ElectronAffinity            1      1717 6556376 122025
# - gmean_fie                        1      1831 6556490 122025
# - gmean_Density                    1      1878 6556537 122026
# - mean_fie                         1      1974 6556633 122026
# - gmean_ThermalConductivity        1      1987 6556646 122026
# - wtd_gmean_fie                    1      2089 6556748 122026
# - mean_ThermalConductivity         1      2312 6556971 122027
# - std_Valence                      1      2487 6557146 122028
# - mean_Valence                     1      2495 6557154 122028
# - mean_atomic_radius               1      2740 6557399 122028
# - wtd_std_Density                  1      2911 6557570 122029
# - wtd_mean_Valence                 1      3558 6558217 122031
# - std_atomic_radius                1      4073 6558732 122033
# - gmean_Valence                    1      4294 6558953 122033
# - wtd_std_atomic_radius            1      4417 6559076 122034
# - wtd_gmean_Density                1      4811 6559470 122035
# - wtd_gmean_Valence                1      5469 6560127 122037
# - gmean_ElectronAffinity           1      6168 6560827 122039
# - entropy_atomic_radius            1      6283 6560942 122040
# - entropy_Density                  1      6497 6561156 122041
# - number_of_elements               1      6761 6561420 122041
# - wtd_std_FusionHeat               1      7199 6561858 122043
# - range_FusionHeat                 1      9446 6564105 122050
# - entropy_ThermalConductivity      1      9732 6564391 122051
# - wtd_range_atomic_radius          1     10177 6564835 122052
# - entropy_fie                      1     10695 6565354 122054
# - wtd_range_fie                    1     10836 6565495 122055
# - entropy_Valence                  1     11343 6566002 122056
# - gmean_atomic_mass                1     11997 6566656 122058
# - range_ThermalConductivity        1     13142 6567801 122062
# - range_Valence                    1     13263 6567922 122062
# - wtd_gmean_atomic_mass            1     13580 6568239 122063
# - wtd_range_ElectronAffinity       1     13889 6568548 122064
# - std_ThermalConductivity          1     14297 6568956 122066
# - entropy_FusionHeat               1     15946 6570605 122071
# - range_Density                    1     16604 6571263 122073
# - wtd_entropy_Density              1     16686 6571345 122074
# - entropy_atomic_mass              1     18919 6573578 122081
# - wtd_entropy_atomic_radius        1     22069 6576728 122091
# - std_Density                      1     23587 6578246 122096
# - wtd_mean_atomic_mass             1     23818 6578477 122097
# - range_atomic_radius              1     23999 6578658 122097
# - std_fie                          1     24325 6578984 122098
# - gmean_FusionHeat                 1     24469 6579128 122099
# - wtd_range_FusionHeat             1     24494 6579153 122099
# - wtd_gmean_FusionHeat             1     24695 6579354 122099
# - std_atomic_mass                  1     24712 6579371 122099
# - mean_FusionHeat                  1     25767 6580426 122103
# - wtd_entropy_fie                  1     26440 6581099 122105
# - mean_Density                     1     27867 6582526 122110
# - wtd_entropy_ElectronAffinity     1     28914 6583573 122113
# - wtd_mean_FusionHeat              1     30846 6585505 122119
# - wtd_mean_ElectronAffinity        1     32432 6587091 122124
# - mean_atomic_mass                 1     32507 6587166 122125
# - range_fie                        1     35036 6589695 122133
# - wtd_gmean_ThermalConductivity    1     43789 6598448 122161
# - wtd_gmean_atomic_radius          1     45486 6600144 122167
# - wtd_entropy_Valence              1     49548 6604207 122180
# - wtd_gmean_ElectronAffinity       1     51213 6605872 122185
# - range_atomic_mass                1     51956 6606614 122187
# - wtd_std_Valence                  1     53322 6607981 122192
# - wtd_entropy_FusionHeat           1     54075 6608734 122194
# - wtd_mean_atomic_radius           1     56456 6611115 122202
# - wtd_std_ElectronAffinity         1     60624 6615283 122215
# - wtd_range_ThermalConductivity    1     61367 6616026 122218
# - wtd_mean_ThermalConductivity     1    108061 6662720 122367
# - range_ElectronAffinity           1    138826 6693485 122465
# - std_ElectronAffinity             1    141384 6696043 122473
#
# Step:  AIC=122019.5
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     wtd_entropy_atomic_mass + range_atomic_mass + wtd_range_atomic_mass +
#     std_atomic_mass + wtd_std_atomic_mass + mean_fie + wtd_mean_fie +
#     gmean_fie + wtd_gmean_fie + entropy_fie + wtd_entropy_fie +
#     range_fie + wtd_range_fie + std_fie + wtd_std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + gmean_atomic_radius + wtd_gmean_atomic_radius +
#     entropy_atomic_radius + wtd_entropy_atomic_radius + range_atomic_radius +
#     wtd_range_atomic_radius + std_atomic_radius + wtd_std_atomic_radius +
#     mean_Density + wtd_mean_Density + gmean_Density + wtd_gmean_Density +
#     entropy_Density + wtd_entropy_Density + range_Density + std_Density +
#     wtd_std_Density + mean_ElectronAffinity + wtd_mean_ElectronAffinity +
#     gmean_ElectronAffinity + wtd_gmean_ElectronAffinity + entropy_ElectronAffinity +
#     wtd_entropy_ElectronAffinity + range_ElectronAffinity + wtd_range_ElectronAffinity +
#     std_ElectronAffinity + wtd_std_ElectronAffinity + mean_FusionHeat +
#     wtd_mean_FusionHeat + gmean_FusionHeat + wtd_gmean_FusionHeat +
#     entropy_FusionHeat + wtd_entropy_FusionHeat + range_FusionHeat +
#     wtd_range_FusionHeat + std_FusionHeat + wtd_std_FusionHeat +
#     mean_ThermalConductivity + wtd_mean_ThermalConductivity +
#     gmean_ThermalConductivity + wtd_gmean_ThermalConductivity +
#     entropy_ThermalConductivity + wtd_entropy_ThermalConductivity +
#     range_ThermalConductivity + wtd_range_ThermalConductivity +
#     std_ThermalConductivity + wtd_std_ThermalConductivity + mean_Valence +
#     wtd_mean_Valence + gmean_Valence + wtd_gmean_Valence + entropy_Valence +
#     wtd_entropy_Valence + range_Valence + wtd_range_Valence +
#     std_Valence + wtd_std_Valence
#
#                                   Df Sum of Sq     RSS    AIC
# - wtd_std_ThermalConductivity      1        30 6554701 122018
# - wtd_mean_Density                 1        37 6554708 122018
# - wtd_entropy_ThermalConductivity  1       276 6554947 122018
# - gmean_atomic_radius              1       393 6555064 122019
# - wtd_std_fie                      1       402 6555073 122019
# - wtd_entropy_atomic_mass          1       476 6555147 122019
# - wtd_range_Valence                1       555 6555226 122019
# - wtd_range_atomic_mass            1       601 6555272 122019
# <none>                                         6554671 122020
# - wtd_std_atomic_mass              1       866 6555537 122020
# - entropy_ElectronAffinity         1       940 6555612 122021
# - std_FusionHeat                   1      1406 6556077 122022
# - wtd_mean_fie                     1      1641 6556312 122023
# - mean_ElectronAffinity            1      1712 6556384 122023
# - gmean_fie                        1      1819 6556490 122023
# - mean_fie                         1      1962 6556633 122024
# - gmean_ThermalConductivity        1      2014 6556685 122024
# - gmean_Density                    1      2022 6556693 122024
# - wtd_gmean_fie                    1      2077 6556748 122024
# - mean_ThermalConductivity         1      2311 6556982 122025
# - std_Valence                      1      2475 6557147 122026
# - mean_Valence                     1      2484 6557156 122026
# - mean_atomic_radius               1      2758 6557429 122026
# - wtd_std_Density                  1      2927 6557598 122027
# - wtd_mean_Valence                 1      3546 6558217 122029
# - std_atomic_radius                1      4062 6558733 122031
# - gmean_Valence                    1      4282 6558953 122031
# - wtd_std_atomic_radius            1      4495 6559166 122032
# - wtd_gmean_Density                1      4837 6559508 122033
# - wtd_gmean_Valence                1      5461 6560132 122035
# - gmean_ElectronAffinity           1      6161 6560832 122037
# - entropy_atomic_radius            1      6271 6560943 122038
# - entropy_Density                  1      6632 6561304 122039
# - number_of_elements               1      6749 6561420 122039
# - wtd_std_FusionHeat               1      7213 6561884 122041
# - range_FusionHeat                 1      9611 6564282 122049
# - entropy_ThermalConductivity      1      9720 6564391 122049
# - wtd_range_atomic_radius          1     10182 6564853 122051
# - entropy_fie                      1     10697 6565369 122052
# - wtd_range_fie                    1     10911 6565582 122053
# - entropy_Valence                  1     11340 6566011 122054
# - gmean_atomic_mass                1     12132 6566803 122057
# - range_Valence                    1     13261 6567932 122060
# - range_ThermalConductivity        1     13316 6567987 122061
# - wtd_gmean_atomic_mass            1     13744 6568415 122062
# - wtd_range_ElectronAffinity       1     13906 6568577 122063
# - std_ThermalConductivity          1     14300 6568972 122064
# - entropy_FusionHeat               1     16069 6570741 122070
# - range_Density                    1     16597 6571268 122071
# - entropy_atomic_mass              1     18963 6573634 122079
# - wtd_entropy_Density              1     19223 6573894 122080
# - wtd_entropy_atomic_radius        1     22156 6576827 122089
# - std_Density                      1     23776 6578447 122094
# - wtd_mean_atomic_mass             1     23830 6578501 122095
# - range_atomic_radius              1     23988 6578659 122095
# - std_fie                          1     24391 6579062 122096
# - gmean_FusionHeat                 1     24464 6579135 122097
# - wtd_gmean_FusionHeat             1     24703 6579374 122097
# - std_atomic_mass                  1     24704 6579375 122097
# - wtd_range_FusionHeat             1     25421 6580093 122100
# - mean_FusionHeat                  1     25824 6580495 122101
# - wtd_entropy_fie                  1     26997 6581668 122105
# - mean_Density                     1     28172 6582843 122109
# - wtd_entropy_ElectronAffinity     1     29190 6583861 122112
# - wtd_mean_FusionHeat              1     31166 6585837 122118
# - wtd_mean_ElectronAffinity        1     32441 6587112 122122
# - mean_atomic_mass                 1     32495 6587166 122123
# - range_fie                        1     35044 6589716 122131
# - wtd_gmean_ThermalConductivity    1     43856 6598527 122159
# - wtd_gmean_atomic_radius          1     45612 6600283 122165
# - wtd_entropy_Valence              1     50975 6605646 122182
# - wtd_gmean_ElectronAffinity       1     51246 6605917 122183
# - range_atomic_mass                1     51944 6606616 122185
# - wtd_std_Valence                  1     53418 6608089 122190
# - wtd_entropy_FusionHeat           1     54435 6609106 122193
# - wtd_mean_atomic_radius           1     56556 6611227 122200
# - wtd_std_ElectronAffinity         1     60684 6615355 122213
# - wtd_range_ThermalConductivity    1     63105 6617776 122221
# - wtd_mean_ThermalConductivity     1    108164 6662835 122366
# - range_ElectronAffinity           1    138959 6693630 122464
# - std_ElectronAffinity             1    141781 6696452 122473
#
# Step:  AIC=122017.6
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     wtd_entropy_atomic_mass + range_atomic_mass + wtd_range_atomic_mass +
#     std_atomic_mass + wtd_std_atomic_mass + mean_fie + wtd_mean_fie +
#     gmean_fie + wtd_gmean_fie + entropy_fie + wtd_entropy_fie +
#     range_fie + wtd_range_fie + std_fie + wtd_std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + gmean_atomic_radius + wtd_gmean_atomic_radius +
#     entropy_atomic_radius + wtd_entropy_atomic_radius + range_atomic_radius +
#     wtd_range_atomic_radius + std_atomic_radius + wtd_std_atomic_radius +
#     mean_Density + wtd_mean_Density + gmean_Density + wtd_gmean_Density +
#     entropy_Density + wtd_entropy_Density + range_Density + std_Density +
#     wtd_std_Density + mean_ElectronAffinity + wtd_mean_ElectronAffinity +
#     gmean_ElectronAffinity + wtd_gmean_ElectronAffinity + entropy_ElectronAffinity +
#     wtd_entropy_ElectronAffinity + range_ElectronAffinity + wtd_range_ElectronAffinity +
#     std_ElectronAffinity + wtd_std_ElectronAffinity + mean_FusionHeat +
#     wtd_mean_FusionHeat + gmean_FusionHeat + wtd_gmean_FusionHeat +
#     entropy_FusionHeat + wtd_entropy_FusionHeat + range_FusionHeat +
#     wtd_range_FusionHeat + std_FusionHeat + wtd_std_FusionHeat +
#     mean_ThermalConductivity + wtd_mean_ThermalConductivity +
#     gmean_ThermalConductivity + wtd_gmean_ThermalConductivity +
#     entropy_ThermalConductivity + wtd_entropy_ThermalConductivity +
#     range_ThermalConductivity + wtd_range_ThermalConductivity +
#     std_ThermalConductivity + mean_Valence + wtd_mean_Valence +
#     gmean_Valence + wtd_gmean_Valence + entropy_Valence + wtd_entropy_Valence +
#     range_Valence + wtd_range_Valence + std_Valence + wtd_std_Valence
#
#                                   Df Sum of Sq     RSS    AIC
# - wtd_mean_Density                 1        31 6554732 122016
# - gmean_atomic_radius              1       381 6555082 122017
# - wtd_std_fie                      1       388 6555089 122017
# - wtd_entropy_ThermalConductivity  1       438 6555139 122017
# - wtd_entropy_atomic_mass          1       509 6555210 122017
# - wtd_range_Valence                1       553 6555254 122017
# <none>                                         6554701 122018
# - wtd_range_atomic_mass            1       618 6555319 122018
# - wtd_std_atomic_mass              1       874 6555575 122018
# - entropy_ElectronAffinity         1       964 6555665 122019
# - std_FusionHeat                   1      1416 6556117 122020
# - wtd_mean_fie                     1      1699 6556400 122021
# - mean_ElectronAffinity            1      1720 6556421 122021
# - gmean_fie                        1      1831 6556532 122022
# - mean_fie                         1      1981 6556682 122022
# - gmean_Density                    1      2103 6556804 122022
# - wtd_gmean_fie                    1      2141 6556842 122023
# - std_Valence                      1      2503 6557204 122024
# - mean_ThermalConductivity         1      2523 6557223 122024
# - mean_Valence                     1      2530 6557231 122024
# - mean_atomic_radius               1      2732 6557433 122024
# - wtd_std_Density                  1      3169 6557870 122026
# - gmean_ThermalConductivity        1      3332 6558033 122026
# - wtd_mean_Valence                 1      3693 6558394 122028
# - std_atomic_radius                1      4103 6558804 122029
# - gmean_Valence                    1      4309 6559010 122030
# - wtd_std_atomic_radius            1      4476 6559177 122030
# - wtd_gmean_Density                1      4819 6559520 122031
# - wtd_gmean_Valence                1      5613 6560314 122034
# - gmean_ElectronAffinity           1      6224 6560925 122036
# - entropy_atomic_radius            1      6311 6561012 122036
# - number_of_elements               1      6835 6561536 122038
# - entropy_Density                  1      6873 6561574 122038
# - wtd_std_FusionHeat               1      7184 6561884 122039
# - range_FusionHeat                 1      9583 6564284 122047
# - entropy_ThermalConductivity      1     10210 6564911 122049
# - wtd_range_atomic_radius          1     10386 6565087 122049
# - entropy_fie                      1     10752 6565452 122050
# - wtd_range_fie                    1     10890 6565591 122051
# - entropy_Valence                  1     11401 6566102 122053
# - gmean_atomic_mass                1     12131 6566832 122055
# - range_Valence                    1     13303 6568004 122059
# - range_ThermalConductivity        1     13340 6568041 122059
# - wtd_gmean_atomic_mass            1     13718 6568419 122060
# - wtd_range_ElectronAffinity       1     13885 6568586 122061
# - entropy_FusionHeat               1     16085 6570786 122068
# - range_Density                    1     16611 6571312 122069
# - std_ThermalConductivity          1     16675 6571376 122070
# - entropy_atomic_mass              1     19094 6573795 122077
# - wtd_entropy_Density              1     20042 6574743 122081
# - wtd_entropy_atomic_radius        1     22885 6577586 122090
# - wtd_mean_atomic_mass             1     23809 6578510 122093
# - range_atomic_radius              1     24173 6578874 122094
# - std_Density                      1     24395 6579096 122095
# - std_fie                          1     24431 6579132 122095
# - gmean_FusionHeat                 1     24446 6579147 122095
# - std_atomic_mass                  1     24760 6579461 122096
# - wtd_gmean_FusionHeat             1     24802 6579503 122096
# - wtd_range_FusionHeat             1     25532 6580233 122098
# - mean_FusionHeat                  1     25795 6580496 122099
# - wtd_entropy_fie                  1     27349 6582050 122104
# - mean_Density                     1     28518 6583219 122108
# - wtd_entropy_ElectronAffinity     1     29336 6584036 122111
# - wtd_mean_FusionHeat              1     31231 6585932 122117
# - mean_atomic_mass                 1     32534 6587235 122121
# - wtd_mean_ElectronAffinity        1     32653 6587354 122121
# - range_fie                        1     35038 6589739 122129
# - wtd_gmean_atomic_radius          1     45697 6600398 122163
# - range_atomic_mass                1     51915 6606616 122183
# - wtd_gmean_ElectronAffinity       1     52042 6606743 122184
# - wtd_entropy_Valence              1     53228 6607929 122188
# - wtd_std_Valence                  1     54251 6608952 122191
# - wtd_entropy_FusionHeat           1     54413 6609114 122191
# - wtd_mean_atomic_radius           1     56696 6611397 122199
# - wtd_std_ElectronAffinity         1     60739 6615440 122212
# - wtd_range_ThermalConductivity    1     63356 6618057 122220
# - wtd_gmean_ThermalConductivity    1    106623 6661324 122359
# - range_ElectronAffinity           1    138950 6693651 122462
# - std_ElectronAffinity             1    141780 6696481 122471
# - wtd_mean_ThermalConductivity     1    192414 6747115 122631
#
# Step:  AIC=122015.7
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     wtd_entropy_atomic_mass + range_atomic_mass + wtd_range_atomic_mass +
#     std_atomic_mass + wtd_std_atomic_mass + mean_fie + wtd_mean_fie +
#     gmean_fie + wtd_gmean_fie + entropy_fie + wtd_entropy_fie +
#     range_fie + wtd_range_fie + std_fie + wtd_std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + gmean_atomic_radius + wtd_gmean_atomic_radius +
#     entropy_atomic_radius + wtd_entropy_atomic_radius + range_atomic_radius +
#     wtd_range_atomic_radius + std_atomic_radius + wtd_std_atomic_radius +
#     mean_Density + gmean_Density + wtd_gmean_Density + entropy_Density +
#     wtd_entropy_Density + range_Density + std_Density + wtd_std_Density +
#     mean_ElectronAffinity + wtd_mean_ElectronAffinity + gmean_ElectronAffinity +
#     wtd_gmean_ElectronAffinity + entropy_ElectronAffinity + wtd_entropy_ElectronAffinity +
#     range_ElectronAffinity + wtd_range_ElectronAffinity + std_ElectronAffinity +
#     wtd_std_ElectronAffinity + mean_FusionHeat + wtd_mean_FusionHeat +
#     gmean_FusionHeat + wtd_gmean_FusionHeat + entropy_FusionHeat +
#     wtd_entropy_FusionHeat + range_FusionHeat + wtd_range_FusionHeat +
#     std_FusionHeat + wtd_std_FusionHeat + mean_ThermalConductivity +
#     wtd_mean_ThermalConductivity + gmean_ThermalConductivity +
#     wtd_gmean_ThermalConductivity + entropy_ThermalConductivity +
#     wtd_entropy_ThermalConductivity + range_ThermalConductivity +
#     wtd_range_ThermalConductivity + std_ThermalConductivity +
#     mean_Valence + wtd_mean_Valence + gmean_Valence + wtd_gmean_Valence +
#     entropy_Valence + wtd_entropy_Valence + range_Valence + wtd_range_Valence +
#     std_Valence + wtd_std_Valence
#
#                                   Df Sum of Sq     RSS    AIC
# - gmean_atomic_radius              1       391 6555123 122015
# - wtd_entropy_ThermalConductivity  1       420 6555152 122015
# - wtd_std_fie                      1       457 6555189 122015
# - wtd_entropy_atomic_mass          1       493 6555225 122015
# - wtd_range_Valence                1       584 6555316 122016
# <none>                                         6554732 122016
# - wtd_range_atomic_mass            1       617 6555349 122016
# - entropy_ElectronAffinity         1       972 6555704 122017
# - wtd_std_atomic_mass              1      1019 6555751 122017
# - std_FusionHeat                   1      1423 6556155 122018
# - wtd_mean_fie                     1      1668 6556400 122019
# - mean_ElectronAffinity            1      1702 6556434 122019
# - gmean_fie                        1      1832 6556564 122020
# - mean_fie                         1      1981 6556713 122020
# - wtd_gmean_fie                    1      2112 6556844 122021
# - mean_ThermalConductivity         1      2528 6557260 122022
# - mean_Valence                     1      2604 6557336 122022
# - std_Valence                      1      2614 6557345 122022
# - mean_atomic_radius               1      2772 6557504 122023
# - gmean_ThermalConductivity        1      3375 6558106 122025
# - wtd_mean_Valence                 1      3745 6558477 122026
# - gmean_Density                    1      4064 6558796 122027
# - std_atomic_radius                1      4132 6558864 122027
# - wtd_std_atomic_radius            1      4447 6559179 122028
# - gmean_Valence                    1      4451 6559183 122028
# - wtd_std_Density                  1      4880 6559612 122030
# - wtd_gmean_Valence                1      5707 6560439 122032
# - gmean_ElectronAffinity           1      6193 6560925 122034
# - entropy_atomic_radius            1      6281 6561013 122034
# - entropy_Density                  1      6931 6561663 122036
# - number_of_elements               1      7121 6561852 122037
# - wtd_std_FusionHeat               1      7551 6562283 122038
# - range_FusionHeat                 1      9661 6564393 122045
# - entropy_ThermalConductivity      1     10360 6565091 122047
# - wtd_range_atomic_radius          1     10424 6565156 122047
# - entropy_fie                      1     10825 6565557 122049
# - wtd_range_fie                    1     11245 6565977 122050
# - entropy_Valence                  1     11473 6566205 122051
# - gmean_atomic_mass                1     12792 6567524 122055
# - range_Valence                    1     13298 6568030 122057
# - range_ThermalConductivity        1     13319 6568051 122057
# - wtd_range_ElectronAffinity       1     13941 6568673 122059
# - wtd_gmean_atomic_mass            1     15663 6570395 122064
# - entropy_FusionHeat               1     16135 6570866 122066
# - range_Density                    1     16588 6571320 122067
# - std_ThermalConductivity          1     16668 6571400 122068
# - wtd_gmean_Density                1     18957 6573688 122075
# - entropy_atomic_mass              1     19077 6573809 122075
# - wtd_entropy_Density              1     20060 6574792 122079
# - wtd_entropy_atomic_radius        1     23204 6577936 122089
# - range_atomic_radius              1     24143 6578875 122092
# - std_fie                          1     24430 6579162 122093
# - gmean_FusionHeat                 1     24672 6579404 122094
# - std_atomic_mass                  1     25445 6580177 122096
# - wtd_range_FusionHeat             1     25507 6580239 122096
# - mean_FusionHeat                  1     26006 6580738 122098
# - wtd_gmean_FusionHeat             1     26008 6580740 122098
# - std_Density                      1     26861 6581593 122101
# - wtd_entropy_fie                  1     27319 6582051 122102
# - wtd_mean_atomic_mass             1     28409 6583141 122106
# - wtd_entropy_ElectronAffinity     1     29377 6584109 122109
# - wtd_mean_FusionHeat              1     32559 6587291 122119
# - wtd_mean_ElectronAffinity        1     32626 6587357 122119
# - range_fie                        1     35249 6589981 122128
# - mean_atomic_mass                 1     35628 6590360 122129
# - wtd_gmean_atomic_radius          1     45723 6600454 122162
# - range_atomic_mass                1     51906 6606638 122181
# - wtd_gmean_ElectronAffinity       1     52057 6606789 122182
# - wtd_entropy_Valence              1     53696 6608428 122187
# - wtd_entropy_FusionHeat           1     54905 6609636 122191
# - wtd_std_Valence                  1     55479 6610211 122193
# - wtd_mean_atomic_radius           1     56702 6611434 122197
# - mean_Density                     1     58977 6613709 122204
# - wtd_std_ElectronAffinity         1     62888 6617620 122217
# - wtd_range_ThermalConductivity    1     65341 6620073 122225
# - wtd_gmean_ThermalConductivity    1    108342 6663074 122362
# - range_ElectronAffinity           1    141146 6695878 122467
# - std_ElectronAffinity             1    141803 6696535 122469
# - wtd_mean_ThermalConductivity     1    192612 6747343 122630
#
# Step:  AIC=122015
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     wtd_entropy_atomic_mass + range_atomic_mass + wtd_range_atomic_mass +
#     std_atomic_mass + wtd_std_atomic_mass + mean_fie + wtd_mean_fie +
#     gmean_fie + wtd_gmean_fie + entropy_fie + wtd_entropy_fie +
#     range_fie + wtd_range_fie + std_fie + wtd_std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + wtd_gmean_atomic_radius + entropy_atomic_radius +
#     wtd_entropy_atomic_radius + range_atomic_radius + wtd_range_atomic_radius +
#     std_atomic_radius + wtd_std_atomic_radius + mean_Density +
#     gmean_Density + wtd_gmean_Density + entropy_Density + wtd_entropy_Density +
#     range_Density + std_Density + wtd_std_Density + mean_ElectronAffinity +
#     wtd_mean_ElectronAffinity + gmean_ElectronAffinity + wtd_gmean_ElectronAffinity +
#     entropy_ElectronAffinity + wtd_entropy_ElectronAffinity +
#     range_ElectronAffinity + wtd_range_ElectronAffinity + std_ElectronAffinity +
#     wtd_std_ElectronAffinity + mean_FusionHeat + wtd_mean_FusionHeat +
#     gmean_FusionHeat + wtd_gmean_FusionHeat + entropy_FusionHeat +
#     wtd_entropy_FusionHeat + range_FusionHeat + wtd_range_FusionHeat +
#     std_FusionHeat + wtd_std_FusionHeat + mean_ThermalConductivity +
#     wtd_mean_ThermalConductivity + gmean_ThermalConductivity +
#     wtd_gmean_ThermalConductivity + entropy_ThermalConductivity +
#     wtd_entropy_ThermalConductivity + range_ThermalConductivity +
#     wtd_range_ThermalConductivity + std_ThermalConductivity +
#     mean_Valence + wtd_mean_Valence + gmean_Valence + wtd_gmean_Valence +
#     entropy_Valence + wtd_entropy_Valence + range_Valence + wtd_range_Valence +
#     std_Valence + wtd_std_Valence
#
#                                   Df Sum of Sq     RSS    AIC
# - wtd_entropy_ThermalConductivity  1       365 6555487 122014
# - wtd_std_fie                      1       458 6555580 122014
# - wtd_entropy_atomic_mass          1       487 6555609 122015
# - wtd_range_Valence                1       526 6555649 122015
# <none>                                         6555123 122015
# - wtd_range_atomic_mass            1       670 6555793 122015
# - wtd_std_atomic_mass              1       835 6555957 122016
# - entropy_ElectronAffinity         1       904 6556026 122016
# - std_FusionHeat                   1      1250 6556372 122017
# - wtd_mean_fie                     1      1411 6556533 122018
# - gmean_fie                        1      1515 6556638 122018
# - mean_fie                         1      1663 6556786 122018
# - wtd_gmean_fie                    1      1825 6556947 122019
# - mean_ElectronAffinity            1      1932 6557054 122019
# - mean_ThermalConductivity         1      2475 6557598 122021
# - std_Valence                      1      2547 6557669 122021
# - mean_Valence                     1      2552 6557675 122021
# - gmean_ThermalConductivity        1      3549 6558672 122024
# - wtd_mean_Valence                 1      3695 6558817 122025
# - gmean_Density                    1      4215 6559338 122027
# - gmean_Valence                    1      4373 6559496 122027
# - wtd_std_Density                  1      4605 6559727 122028
# - wtd_std_atomic_radius            1      5261 6560383 122030
# - wtd_gmean_Valence                1      5634 6560757 122031
# - entropy_atomic_radius            1      6217 6561339 122033
# - gmean_ElectronAffinity           1      6636 6561759 122034
# - entropy_Density                  1      6789 6561912 122035
# - number_of_elements               1      7068 6562191 122036
# - wtd_std_FusionHeat               1      7232 6562354 122036
# - range_FusionHeat                 1     10028 6565151 122045
# - wtd_range_atomic_radius          1     10325 6565447 122046
# - entropy_fie                      1     10525 6565647 122047
# - entropy_ThermalConductivity      1     10570 6565693 122047
# - wtd_range_fie                    1     10955 6566077 122048
# - entropy_Valence                  1     11208 6566331 122049
# - std_atomic_radius                1     11280 6566403 122050
# - gmean_atomic_mass                1     12402 6567524 122053
# - range_Valence                    1     13334 6568457 122056
# - range_ThermalConductivity        1     13536 6568659 122057
# - wtd_range_ElectronAffinity       1     14362 6569484 122060
# - wtd_gmean_atomic_mass            1     15275 6570398 122062
# - entropy_FusionHeat               1     16049 6571172 122065
# - range_Density                    1     16871 6571994 122068
# - std_ThermalConductivity          1     16878 6572001 122068
# - wtd_gmean_Density                1     18975 6574097 122074
# - entropy_atomic_mass              1     19258 6574380 122075
# - wtd_entropy_Density              1     19687 6574810 122077
# - wtd_entropy_atomic_radius        1     23065 6578188 122088
# - gmean_FusionHeat                 1     24303 6579425 122092
# - std_fie                          1     24326 6579449 122092
# - std_atomic_mass                  1     25056 6580178 122094
# - wtd_range_FusionHeat             1     25270 6580393 122095
# - wtd_gmean_FusionHeat             1     25618 6580740 122096
# - mean_FusionHeat                  1     25642 6580765 122096
# - range_atomic_radius              1     25700 6580823 122096
# - wtd_entropy_fie                  1     26928 6582051 122100
# - std_Density                      1     26950 6582072 122100
# - wtd_mean_atomic_mass             1     28026 6583148 122104
# - wtd_entropy_ElectronAffinity     1     29000 6584123 122107
# - wtd_mean_FusionHeat              1     32171 6587294 122117
# - wtd_mean_ElectronAffinity        1     34877 6589999 122126
# - range_fie                        1     35135 6590258 122127
# - mean_atomic_mass                 1     35355 6590477 122127
# - mean_atomic_radius               1     40931 6596054 122145
# - range_atomic_mass                1     51698 6606821 122180
# - wtd_entropy_Valence              1     53638 6608761 122186
# - wtd_entropy_FusionHeat           1     54530 6609653 122189
# - wtd_gmean_ElectronAffinity       1     55407 6610529 122192
# - wtd_std_Valence                  1     55536 6610659 122192
# - mean_Density                     1     60388 6615511 122208
# - wtd_std_ElectronAffinity         1     64101 6619223 122220
# - wtd_range_ThermalConductivity    1     65014 6620136 122223
# - wtd_gmean_atomic_radius          1     95206 6650328 122320
# - wtd_gmean_ThermalConductivity    1    110267 6665390 122368
# - wtd_mean_atomic_radius           1    110670 6665792 122369
# - range_ElectronAffinity           1    141844 6696967 122468
# - std_ElectronAffinity             1    143482 6698605 122473
# - wtd_mean_ThermalConductivity     1    193926 6749048 122633
#
# Step:  AIC=122014.1
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     wtd_entropy_atomic_mass + range_atomic_mass + wtd_range_atomic_mass +
#     std_atomic_mass + wtd_std_atomic_mass + mean_fie + wtd_mean_fie +
#     gmean_fie + wtd_gmean_fie + entropy_fie + wtd_entropy_fie +
#     range_fie + wtd_range_fie + std_fie + wtd_std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + wtd_gmean_atomic_radius + entropy_atomic_radius +
#     wtd_entropy_atomic_radius + range_atomic_radius + wtd_range_atomic_radius +
#     std_atomic_radius + wtd_std_atomic_radius + mean_Density +
#     gmean_Density + wtd_gmean_Density + entropy_Density + wtd_entropy_Density +
#     range_Density + std_Density + wtd_std_Density + mean_ElectronAffinity +
#     wtd_mean_ElectronAffinity + gmean_ElectronAffinity + wtd_gmean_ElectronAffinity +
#     entropy_ElectronAffinity + wtd_entropy_ElectronAffinity +
#     range_ElectronAffinity + wtd_range_ElectronAffinity + std_ElectronAffinity +
#     wtd_std_ElectronAffinity + mean_FusionHeat + wtd_mean_FusionHeat +
#     gmean_FusionHeat + wtd_gmean_FusionHeat + entropy_FusionHeat +
#     wtd_entropy_FusionHeat + range_FusionHeat + wtd_range_FusionHeat +
#     std_FusionHeat + wtd_std_FusionHeat + mean_ThermalConductivity +
#     wtd_mean_ThermalConductivity + gmean_ThermalConductivity +
#     wtd_gmean_ThermalConductivity + entropy_ThermalConductivity +
#     range_ThermalConductivity + wtd_range_ThermalConductivity +
#     std_ThermalConductivity + mean_Valence + wtd_mean_Valence +
#     gmean_Valence + wtd_gmean_Valence + entropy_Valence + wtd_entropy_Valence +
#     range_Valence + wtd_range_Valence + std_Valence + wtd_std_Valence
#
#                                 Df Sum of Sq     RSS    AIC
# - wtd_entropy_atomic_mass        1       385 6555872 122013
# - wtd_std_fie                    1       466 6555953 122014
# - wtd_range_Valence              1       531 6556018 122014
# <none>                                       6555487 122014
# - wtd_range_atomic_mass          1       632 6556119 122014
# - wtd_std_atomic_mass            1       787 6556274 122015
# - entropy_ElectronAffinity       1       818 6556305 122015
# - std_FusionHeat                 1      1290 6556778 122016
# - wtd_mean_fie                   1      1407 6556895 122017
# - gmean_fie                      1      1516 6557003 122017
# - mean_fie                       1      1659 6557146 122018
# - wtd_gmean_fie                  1      1825 6557312 122018
# - mean_ElectronAffinity          1      2174 6557662 122019
# - mean_Valence                   1      2436 6557923 122020
# - std_Valence                    1      2476 6557963 122020
# - mean_ThermalConductivity       1      2739 6558226 122021
# - gmean_ThermalConductivity      1      3404 6558891 122023
# - wtd_mean_Valence               1      3564 6559051 122024
# - gmean_Valence                  1      4245 6559733 122026
# - gmean_Density                  1      4446 6559933 122027
# - wtd_std_Density                1      4571 6560058 122027
# - wtd_gmean_Valence              1      5484 6560971 122030
# - wtd_std_atomic_radius          1      5539 6561026 122030
# - entropy_atomic_radius          1      6424 6561911 122033
# - entropy_Density                1      6467 6561954 122033
# - number_of_elements             1      7119 6562606 122035
# - gmean_ElectronAffinity         1      7275 6562762 122036
# - wtd_std_FusionHeat             1      7309 6562797 122036
# - range_FusionHeat               1      9858 6565345 122044
# - wtd_range_atomic_radius        1     10144 6565631 122045
# - entropy_fie                    1     10918 6566405 122048
# - std_atomic_radius              1     11012 6566499 122048
# - entropy_Valence                1     11142 6566629 122048
# - wtd_range_fie                  1     11503 6566990 122049
# - gmean_atomic_mass              1     12618 6568105 122053
# - range_Valence                  1     13469 6568956 122056
# - wtd_range_ElectronAffinity     1     14308 6569795 122059
# - wtd_gmean_atomic_mass          1     15371 6570858 122062
# - range_ThermalConductivity      1     15435 6570922 122062
# - entropy_FusionHeat             1     15742 6571229 122063
# - range_Density                  1     16977 6572464 122067
# - entropy_ThermalConductivity    1     18649 6574137 122073
# - wtd_gmean_Density              1     18824 6574311 122073
# - entropy_atomic_mass            1     18909 6574396 122073
# - wtd_entropy_Density            1     19334 6574821 122075
# - std_ThermalConductivity        1     20630 6576118 122079
# - std_fie                        1     24480 6579967 122091
# - std_atomic_mass                1     24732 6580219 122092
# - gmean_FusionHeat               1     24846 6580333 122093
# - wtd_range_FusionHeat           1     25040 6580527 122093
# - wtd_entropy_atomic_radius      1     25519 6581006 122095
# - range_atomic_radius            1     25585 6581073 122095
# - mean_FusionHeat                1     25903 6581391 122096
# - wtd_gmean_FusionHeat           1     25927 6581414 122096
# - std_Density                    1     26941 6582428 122099
# - wtd_entropy_fie                1     27482 6582969 122101
# - wtd_mean_atomic_mass           1     28110 6583597 122103
# - wtd_entropy_ElectronAffinity   1     28849 6584336 122106
# - wtd_mean_FusionHeat            1     32295 6587782 122117
# - range_fie                      1     35412 6590899 122127
# - mean_atomic_mass               1     35723 6591210 122128
# - wtd_mean_ElectronAffinity      1     36275 6591763 122129
# - mean_atomic_radius             1     45060 6600547 122158
# - range_atomic_mass              1     51354 6606841 122178
# - wtd_entropy_Valence            1     54077 6609564 122187
# - wtd_entropy_FusionHeat         1     54288 6609776 122188
# - wtd_std_Valence                1     55281 6610768 122191
# - wtd_gmean_ElectronAffinity     1     58085 6613573 122200
# - mean_Density                   1     61398 6616885 122210
# - wtd_std_ElectronAffinity       1     65701 6621188 122224
# - wtd_range_ThermalConductivity  1     84685 6640172 122285
# - wtd_gmean_atomic_radius        1     96023 6651510 122321
# - wtd_gmean_ThermalConductivity  1    110754 6666241 122368
# - wtd_mean_atomic_radius         1    112538 6668025 122374
# - range_ElectronAffinity         1    141659 6697146 122467
# - std_ElectronAffinity           1    143972 6699460 122474
# - wtd_mean_ThermalConductivity   1    195425 6750913 122637
#
# Step:  AIC=122013.4
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     range_atomic_mass + wtd_range_atomic_mass + std_atomic_mass +
#     wtd_std_atomic_mass + mean_fie + wtd_mean_fie + gmean_fie +
#     wtd_gmean_fie + entropy_fie + wtd_entropy_fie + range_fie +
#     wtd_range_fie + std_fie + wtd_std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + wtd_gmean_atomic_radius + entropy_atomic_radius +
#     wtd_entropy_atomic_radius + range_atomic_radius + wtd_range_atomic_radius +
#     std_atomic_radius + wtd_std_atomic_radius + mean_Density +
#     gmean_Density + wtd_gmean_Density + entropy_Density + wtd_entropy_Density +
#     range_Density + std_Density + wtd_std_Density + mean_ElectronAffinity +
#     wtd_mean_ElectronAffinity + gmean_ElectronAffinity + wtd_gmean_ElectronAffinity +
#     entropy_ElectronAffinity + wtd_entropy_ElectronAffinity +
#     range_ElectronAffinity + wtd_range_ElectronAffinity + std_ElectronAffinity +
#     wtd_std_ElectronAffinity + mean_FusionHeat + wtd_mean_FusionHeat +
#     gmean_FusionHeat + wtd_gmean_FusionHeat + entropy_FusionHeat +
#     wtd_entropy_FusionHeat + range_FusionHeat + wtd_range_FusionHeat +
#     std_FusionHeat + wtd_std_FusionHeat + mean_ThermalConductivity +
#     wtd_mean_ThermalConductivity + gmean_ThermalConductivity +
#     wtd_gmean_ThermalConductivity + entropy_ThermalConductivity +
#     range_ThermalConductivity + wtd_range_ThermalConductivity +
#     std_ThermalConductivity + mean_Valence + wtd_mean_Valence +
#     gmean_Valence + wtd_gmean_Valence + entropy_Valence + wtd_entropy_Valence +
#     range_Valence + wtd_range_Valence + std_Valence + wtd_std_Valence
#
#                                 Df Sum of Sq     RSS    AIC
# - wtd_range_atomic_mass          1       386 6556258 122013
# - wtd_range_Valence              1       452 6556325 122013
# - wtd_std_fie                    1       462 6556334 122013
# <none>                                       6555872 122013
# - wtd_std_atomic_mass            1       638 6556510 122013
# - entropy_ElectronAffinity       1       744 6556616 122014
# - std_FusionHeat                 1      1229 6557101 122015
# - wtd_mean_fie                   1      1414 6557286 122016
# - gmean_fie                      1      1492 6557364 122016
# - mean_fie                       1      1631 6557503 122017
# - wtd_gmean_fie                  1      1841 6557714 122017
# - mean_ElectronAffinity          1      2174 6558046 122018
# - mean_Valence                   1      2340 6558212 122019
# - std_Valence                    1      2608 6558480 122020
# - mean_ThermalConductivity       1      2860 6558732 122021
# - gmean_ThermalConductivity      1      3210 6559082 122022
# - wtd_mean_Valence               1      3508 6559380 122023
# - gmean_Valence                  1      4127 6559999 122025
# - wtd_std_Density                1      4208 6560080 122025
# - gmean_Density                  1      4280 6560152 122025
# - wtd_gmean_Valence              1      5433 6561305 122029
# - wtd_std_atomic_radius          1      5517 6561389 122029
# - entropy_atomic_radius          1      6104 6561976 122031
# - entropy_Density                1      6161 6562033 122031
# - wtd_std_FusionHeat             1      7019 6562891 122034
# - number_of_elements             1      7332 6563204 122035
# - gmean_ElectronAffinity         1      7346 6563218 122035
# - wtd_range_atomic_radius        1      9780 6565652 122043
# - range_FusionHeat               1     10004 6565876 122044
# - entropy_fie                    1     10871 6566743 122047
# - std_atomic_radius              1     11173 6567045 122048
# - wtd_range_fie                  1     11508 6567380 122049
# - entropy_Valence                1     11648 6567520 122049
# - range_Valence                  1     13294 6569166 122054
# - gmean_atomic_mass              1     13574 6569446 122055
# - wtd_range_ElectronAffinity     1     14934 6570806 122060
# - range_ThermalConductivity      1     15185 6571057 122061
# - entropy_FusionHeat             1     15762 6571634 122062
# - range_Density                  1     16842 6572714 122066
# - wtd_gmean_atomic_mass          1     17302 6573174 122067
# - entropy_ThermalConductivity    1     19069 6574941 122073
# - wtd_gmean_Density              1     19750 6575622 122075
# - entropy_atomic_mass            1     20000 6575872 122076
# - std_ThermalConductivity        1     20354 6576226 122077
# - wtd_entropy_Density            1     20663 6576535 122078
# - std_atomic_mass                1     24455 6580327 122091
# - std_fie                        1     24784 6580656 122092
# - wtd_range_FusionHeat           1     24939 6580811 122092
# - gmean_FusionHeat               1     25148 6581020 122093
# - range_atomic_radius            1     25527 6581399 122094
# - wtd_gmean_FusionHeat           1     25919 6581791 122095
# - mean_FusionHeat                1     26017 6581889 122096
# - std_Density                    1     26564 6582436 122097
# - wtd_entropy_fie                1     27139 6583011 122099
# - wtd_entropy_ElectronAffinity   1     28542 6584414 122104
# - wtd_mean_FusionHeat            1     32154 6588026 122115
# - wtd_mean_atomic_mass           1     32243 6588115 122116
# - range_fie                      1     35733 6591605 122127
# - wtd_mean_ElectronAffinity      1     36491 6592363 122129
# - mean_atomic_mass               1     39890 6595762 122140
# - wtd_entropy_atomic_radius      1     44710 6600582 122156
# - mean_atomic_radius             1     46200 6602072 122161
# - range_atomic_mass              1     50977 6606849 122176
# - wtd_entropy_Valence            1     53919 6609791 122186
# - wtd_entropy_FusionHeat         1     54430 6610302 122187
# - wtd_std_Valence                1     55990 6611862 122192
# - wtd_gmean_ElectronAffinity     1     58495 6614367 122200
# - mean_Density                   1     61881 6617754 122211
# - wtd_std_ElectronAffinity       1     65316 6621189 122222
# - wtd_range_ThermalConductivity  1     84740 6640612 122284
# - wtd_gmean_atomic_radius        1     97274 6653146 122325
# - wtd_gmean_ThermalConductivity  1    112789 6668661 122374
# - wtd_mean_atomic_radius         1    114113 6669985 122378
# - range_ElectronAffinity         1    141277 6697149 122465
# - std_ElectronAffinity           1    143588 6699460 122472
# - wtd_mean_ThermalConductivity   1    196079 6751951 122638
#
# Step:  AIC=122012.6
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     range_atomic_mass + std_atomic_mass + wtd_std_atomic_mass +
#     mean_fie + wtd_mean_fie + gmean_fie + wtd_gmean_fie + entropy_fie +
#     wtd_entropy_fie + range_fie + wtd_range_fie + std_fie + wtd_std_fie +
#     mean_atomic_radius + wtd_mean_atomic_radius + wtd_gmean_atomic_radius +
#     entropy_atomic_radius + wtd_entropy_atomic_radius + range_atomic_radius +
#     wtd_range_atomic_radius + std_atomic_radius + wtd_std_atomic_radius +
#     mean_Density + gmean_Density + wtd_gmean_Density + entropy_Density +
#     wtd_entropy_Density + range_Density + std_Density + wtd_std_Density +
# ...
# - gmean_Valence                  1      4152 6560766 122023
# - gmean_Density                  1      4352 6560966 122024
# - wtd_std_Density                1      4450 6561064 122024
# - wtd_std_atomic_radius          1      5139 6561753 122026
# - wtd_gmean_Valence              1      5463 6562077 122028
# - entropy_atomic_radius          1      5947 6562560 122029
# - entropy_Density                1      6559 6563172 122031
# - wtd_std_FusionHeat             1      6939 6563553 122032
# - gmean_ElectronAffinity         1      7213 6563827 122033
# - number_of_elements             1      7689 6564302 122035
# - entropy_fie                    1     10458 6567071 122044
# - range_FusionHeat               1     10999 6567613 122045
# - entropy_Valence                1     11247 6567861 122046
# - std_atomic_radius              1     11609 6568222 122047
# - wtd_range_fie                  1     12073 6568687 122049
# - range_Valence                  1     13232 6569845 122053
# - gmean_atomic_mass              1     13954 6570567 122055
# - wtd_range_atomic_radius        1     15011 6571625 122058
# - range_ThermalConductivity      1     15304 6571918 122059
# - entropy_FusionHeat             1     15808 6572422 122061
# - wtd_range_ElectronAffinity     1     16449 6573063 122063
# - range_Density                  1     16867 6573481 122064
# - wtd_gmean_atomic_mass          1     17099 6573713 122065
# - wtd_gmean_Density              1     19359 6575972 122072
# - entropy_ThermalConductivity    1     19383 6575996 122073
# - entropy_atomic_mass            1     19782 6576396 122074
# - std_ThermalConductivity        1     20629 6577243 122077
# - wtd_entropy_Density            1     22042 6578656 122081
# - wtd_range_FusionHeat           1     24430 6581043 122089
# - std_atomic_mass                1     24494 6581108 122089
# - std_fie                        1     24533 6581147 122089
# - gmean_FusionHeat               1     24844 6581457 122090
# - wtd_gmean_FusionHeat           1     25340 6581954 122092
# - range_atomic_radius            1     25443 6582057 122092
# - mean_FusionHeat                1     25571 6582185 122093
# - std_Density                    1     27001 6583615 122097
# - wtd_entropy_fie                1     27279 6583893 122098
# - wtd_entropy_ElectronAffinity   1     28901 6585514 122103
# - wtd_mean_FusionHeat            1     31498 6588112 122112
# - wtd_mean_atomic_mass           1     33257 6589870 122117
# - range_fie                      1     35389 6592003 122124
# - wtd_mean_ElectronAffinity      1     36153 6592767 122127
# - mean_atomic_mass               1     39759 6596372 122138
# - wtd_entropy_atomic_radius      1     46099 6602713 122159
# - mean_atomic_radius             1     46974 6603588 122162
# - range_atomic_mass              1     51041 6607654 122175
# - wtd_entropy_FusionHeat         1     54059 6610672 122184
# - wtd_std_Valence                1     56654 6613268 122193
# - wtd_gmean_ElectronAffinity     1     58892 6615505 122200
# - wtd_entropy_Valence            1     60492 6617106 122205
# - mean_Density                   1     61859 6618472 122209
# - wtd_std_ElectronAffinity       1     65702 6622316 122222
# - wtd_range_ThermalConductivity  1     89408 6646021 122298
# - wtd_gmean_atomic_radius        1     96796 6653410 122321
# - wtd_gmean_ThermalConductivity  1    112655 6669269 122372
# - wtd_mean_atomic_radius         1    114740 6671353 122379
# - range_ElectronAffinity         1    141760 6698373 122465
# - std_ElectronAffinity           1    143427 6700041 122470
# - wtd_mean_ThermalConductivity   1    202441 6759055 122656
#
# Step:  AIC=122011.4
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     range_atomic_mass + std_atomic_mass + wtd_std_atomic_mass +
#     mean_fie + wtd_mean_fie + gmean_fie + wtd_gmean_fie + entropy_fie +
#     wtd_entropy_fie + range_fie + wtd_range_fie + std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + wtd_gmean_atomic_radius + entropy_atomic_radius +
#     wtd_entropy_atomic_radius + range_atomic_radius + wtd_range_atomic_radius +
#     std_atomic_radius + wtd_std_atomic_radius + mean_Density +
#     gmean_Density + wtd_gmean_Density + entropy_Density + wtd_entropy_Density +
#     range_Density + std_Density + wtd_std_Density + mean_ElectronAffinity +
#     wtd_mean_ElectronAffinity + gmean_ElectronAffinity + wtd_gmean_ElectronAffinity +
#     entropy_ElectronAffinity + wtd_entropy_ElectronAffinity +
#     range_ElectronAffinity + wtd_range_ElectronAffinity + std_ElectronAffinity +
#     wtd_std_ElectronAffinity + mean_FusionHeat + wtd_mean_FusionHeat +
#     gmean_FusionHeat + wtd_gmean_FusionHeat + entropy_FusionHeat +
#     wtd_entropy_FusionHeat + range_FusionHeat + wtd_range_FusionHeat +
#     std_FusionHeat + wtd_std_FusionHeat + mean_ThermalConductivity +
#     wtd_mean_ThermalConductivity + gmean_ThermalConductivity +
#     wtd_gmean_ThermalConductivity + entropy_ThermalConductivity +
#     range_ThermalConductivity + wtd_range_ThermalConductivity +
#     std_ThermalConductivity + mean_Valence + wtd_mean_Valence +
#     gmean_Valence + wtd_gmean_Valence + entropy_Valence + wtd_entropy_Valence +
#     range_Valence + std_Valence + wtd_std_Valence
#
#                                 Df Sum of Sq     RSS    AIC
# <none>                                       6557097 122011
# - wtd_std_atomic_mass            1       632 6557729 122011
# - entropy_ElectronAffinity       1       725 6557822 122012
# - std_FusionHeat                 1      1014 6558110 122013
# - mean_ElectronAffinity          1      2083 6559180 122016
# - mean_Valence                   1      2155 6559252 122016
# - std_Valence                    1      2540 6559637 122018
# - mean_ThermalConductivity       1      2715 6559811 122018
# - wtd_mean_Valence               1      3259 6560356 122020
# - gmean_ThermalConductivity      1      3698 6560794 122021
# - gmean_Valence                  1      3977 6561073 122022
# - gmean_Density                  1      4111 6561207 122023
# - wtd_std_Density                1      4278 6561375 122023
# - wtd_gmean_Valence              1      5298 6562394 122027
# - wtd_std_atomic_radius          1      5904 6563000 122029
# - gmean_fie                      1      5922 6563019 122029
# - entropy_Density                1      6161 6563258 122029
# - mean_fie                       1      6270 6563367 122030
# - wtd_std_FusionHeat             1      6546 6563642 122031
# - entropy_atomic_radius          1      6885 6563982 122032
# - gmean_ElectronAffinity         1      7399 6564496 122033
# - number_of_elements             1      8105 6565202 122036
# - range_FusionHeat               1     10766 6567863 122044
# - std_atomic_radius              1     11281 6568378 122046
# - entropy_fie                    1     11956 6569052 122048
# - entropy_Valence                1     12003 6569100 122048
# - wtd_range_fie                  1     12270 6569366 122049
# - range_Valence                  1     13126 6570222 122052
# - wtd_mean_fie                   1     13282 6570378 122052
# - gmean_atomic_mass              1     14129 6571226 122055
# - wtd_range_atomic_radius        1     15352 6572449 122059
# - wtd_gmean_fie                  1     15388 6572484 122059
# - entropy_FusionHeat             1     15427 6572524 122059
# - range_ThermalConductivity      1     15652 6572749 122060
# - wtd_range_ElectronAffinity     1     16411 6573507 122063
# - wtd_gmean_atomic_mass          1     16966 6574063 122064
# - range_Density                  1     17351 6574447 122066
# - entropy_ThermalConductivity    1     19015 6576111 122071
# - entropy_atomic_mass            1     19470 6576566 122072
# - std_ThermalConductivity        1     20818 6577914 122077
# - wtd_entropy_Density            1     21633 6578730 122079
# - wtd_gmean_Density              1     22195 6579291 122081
# - std_atomic_mass                1     24477 6581573 122089
# - wtd_range_FusionHeat           1     24479 6581575 122089
# - gmean_FusionHeat               1     24667 6581763 122089
# - wtd_gmean_FusionHeat           1     25141 6582237 122091
# - mean_FusionHeat                1     25478 6582575 122092
# - range_atomic_radius            1     25819 6582915 122093
# - std_Density                    1     27016 6584112 122097
# - wtd_entropy_fie                1     27141 6584237 122097
# - wtd_entropy_ElectronAffinity   1     29455 6586551 122105
# - wtd_mean_FusionHeat            1     31309 6588406 122111
# - wtd_mean_atomic_mass           1     33313 6590409 122117
# - range_fie                      1     35132 6592229 122123
# - wtd_mean_ElectronAffinity      1     36096 6593192 122126
# - mean_atomic_mass               1     40339 6597436 122140
# - wtd_entropy_atomic_radius      1     46519 6603616 122160
# - mean_atomic_radius             1     48339 6605435 122166
# - range_atomic_mass              1     50940 6608037 122174
# - wtd_entropy_FusionHeat         1     53603 6610700 122182
# - std_fie                        1     55609 6612706 122189
# - wtd_std_Valence                1     56950 6614047 122193
# - wtd_gmean_ElectronAffinity     1     58833 6615930 122199
# - wtd_entropy_Valence            1     61965 6619062 122209
# - mean_Density                   1     61987 6619083 122209
# - wtd_std_ElectronAffinity       1     68583 6625679 122231
# - wtd_range_ThermalConductivity  1     89476 6646573 122298
# - wtd_gmean_atomic_radius        1    103554 6660651 122343
# - wtd_gmean_ThermalConductivity  1    112829 6669925 122372
# - wtd_mean_atomic_radius         1    121874 6678970 122401
# - range_ElectronAffinity         1    141567 6698664 122464
# - std_ElectronAffinity           1    143722 6700818 122470
# - wtd_mean_ThermalConductivity   1    203755 6760852 122660
# Call:
# lm(formula = critical_temp ~ number_of_elements + mean_atomic_mass +
#     wtd_mean_atomic_mass + gmean_atomic_mass + wtd_gmean_atomic_mass +
#     entropy_atomic_mass + range_atomic_mass + std_atomic_mass +
#     wtd_std_atomic_mass + mean_fie + wtd_mean_fie + gmean_fie +
#     wtd_gmean_fie + entropy_fie + wtd_entropy_fie + range_fie +
#     wtd_range_fie + std_fie + mean_atomic_radius + wtd_mean_atomic_radius +
#     wtd_gmean_atomic_radius + entropy_atomic_radius + wtd_entropy_atomic_radius +
#     range_atomic_radius + wtd_range_atomic_radius + std_atomic_radius +
#     wtd_std_atomic_radius + mean_Density + gmean_Density + wtd_gmean_Density +
#     entropy_Density + wtd_entropy_Density + range_Density + std_Density +
#     wtd_std_Density + mean_ElectronAffinity + wtd_mean_ElectronAffinity +
#     gmean_ElectronAffinity + wtd_gmean_ElectronAffinity + entropy_ElectronAffinity +
#     wtd_entropy_ElectronAffinity + range_ElectronAffinity + wtd_range_ElectronAffinity +
#     std_ElectronAffinity + wtd_std_ElectronAffinity + mean_FusionHeat +
#     wtd_mean_FusionHeat + gmean_FusionHeat + wtd_gmean_FusionHeat +
#     entropy_FusionHeat + wtd_entropy_FusionHeat + range_FusionHeat +
#     wtd_range_FusionHeat + std_FusionHeat + wtd_std_FusionHeat +
#     mean_ThermalConductivity + wtd_mean_ThermalConductivity +
#     gmean_ThermalConductivity + wtd_gmean_ThermalConductivity +
#     entropy_ThermalConductivity + range_ThermalConductivity +
#     wtd_range_ThermalConductivity + std_ThermalConductivity +
#     mean_Valence + wtd_mean_Valence + gmean_Valence + wtd_gmean_Valence +
#     entropy_Valence + wtd_entropy_Valence + range_Valence + std_Valence +
#     wtd_std_Valence, data = supercon_data)
#
# Coefficients:
#                   (Intercept)             number_of_elements
#                    -1.991e+01                     -3.738e+00
#              mean_atomic_mass           wtd_mean_atomic_mass
#                     8.633e-01                     -9.010e-01
#             gmean_atomic_mass          wtd_gmean_atomic_mass
#                    -5.268e-01                      6.562e-01
#           entropy_atomic_mass              range_atomic_mass
#                    -3.289e+01                      2.107e-01
#               std_atomic_mass            wtd_std_atomic_mass
#                    -5.344e-01                      7.312e-02
#                      mean_fie                   wtd_mean_fie
#                     1.967e-01                     -2.361e-01
#                     gmean_fie                  wtd_gmean_fie
#                    -1.881e-01                      2.552e-01
#                   entropy_fie                wtd_entropy_fie
#                    -1.193e+02                      4.167e+01
#                     range_fie                  wtd_range_fie
#                     6.802e-02                      2.048e-02
#                       std_fie             mean_atomic_radius
#                    -2.168e-01                     -3.418e-01
#        wtd_mean_atomic_radius        wtd_gmean_atomic_radius
#                     3.072e+00                     -2.676e+00
#         entropy_atomic_radius      wtd_entropy_atomic_radius
#                     7.988e+01                      4.803e+01
#           range_atomic_radius        wtd_range_atomic_radius
#                     1.992e-01                     -8.852e-02
#             std_atomic_radius          wtd_std_atomic_radius
#                    -4.267e-01                     -2.713e-01
#                  mean_Density                  gmean_Density
#                    -4.946e-03                      1.285e-03
#             wtd_gmean_Density                entropy_Density
#                     2.210e-03                      1.461e+01
#           wtd_entropy_Density                  range_Density
#                    -1.776e+01                     -1.607e-03
#                   std_Density                wtd_std_Density
#                     6.092e-03                     -1.528e-03
#         mean_ElectronAffinity      wtd_mean_ElectronAffinity
#                    -1.182e-01                      5.315e-01
#        gmean_ElectronAffinity     wtd_gmean_ElectronAffinity
#                     1.906e-01                     -5.882e-01
#      entropy_ElectronAffinity   wtd_entropy_ElectronAffinity
#                     3.917e+00                     -2.103e+01
#        range_ElectronAffinity     wtd_range_ElectronAffinity
#                    -3.660e-01                     -1.439e-01
#          std_ElectronAffinity       wtd_std_ElectronAffinity
#                     1.246e+00                     -5.506e-01
#               mean_FusionHeat            wtd_mean_FusionHeat
#                     1.686e+00                     -1.870e+00
#              gmean_FusionHeat           wtd_gmean_FusionHeat
#                    -1.533e+00                      1.574e+00
#            entropy_FusionHeat         wtd_entropy_FusionHeat
#                    -1.882e+01                      2.444e+01
#              range_FusionHeat           wtd_range_FusionHeat
#                    -3.857e-01                      5.716e-01
#                std_FusionHeat             wtd_std_FusionHeat
#                    -4.610e-01                      6.892e-01
#      mean_ThermalConductivity   wtd_mean_ThermalConductivity
#                    -6.602e-02                      5.162e-01
#     gmean_ThermalConductivity  wtd_gmean_ThermalConductivity
#                    -6.610e-02                     -3.062e-01
#   entropy_ThermalConductivity      range_ThermalConductivity
#                     1.233e+01                     -9.130e-02
# wtd_range_ThermalConductivity        std_ThermalConductivity
#                    -2.365e-01                      2.914e-01
#                  mean_Valence               wtd_mean_Valence
#                    -1.559e+01                      2.255e+01
#                 gmean_Valence              wtd_gmean_Valence
#                     2.005e+01                     -2.718e+01
#               entropy_Valence            wtd_entropy_Valence
#                     7.384e+01                     -6.799e+01
#                 range_Valence                    std_Valence
#                     4.734e+00                      6.829e+00
#               wtd_std_Valence
#                    -2.505e+01

# %%
n = nrow(supercon_data)
fit_back_bic = step(model_full, direction = "backward", k=log(n))
fit_back_bic
# Out:
# Start:  AIC=122674.6
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     wtd_entropy_atomic_mass + range_atomic_mass + wtd_range_atomic_mass +
#     std_atomic_mass + wtd_std_atomic_mass + mean_fie + wtd_mean_fie +
#     gmean_fie + wtd_gmean_fie + entropy_fie + wtd_entropy_fie +
#     range_fie + wtd_range_fie + std_fie + wtd_std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + gmean_atomic_radius + wtd_gmean_atomic_radius +
#     entropy_atomic_radius + wtd_entropy_atomic_radius + range_atomic_radius +
#     wtd_range_atomic_radius + std_atomic_radius + wtd_std_atomic_radius +
#     mean_Density + wtd_mean_Density + gmean_Density + wtd_gmean_Density +
#     entropy_Density + wtd_entropy_Density + range_Density + wtd_range_Density +
#     std_Density + wtd_std_Density + mean_ElectronAffinity + wtd_mean_ElectronAffinity +
#     gmean_ElectronAffinity + wtd_gmean_ElectronAffinity + entropy_ElectronAffinity +
#     wtd_entropy_ElectronAffinity + range_ElectronAffinity + wtd_range_ElectronAffinity +
#     std_ElectronAffinity + wtd_std_ElectronAffinity + mean_FusionHeat +
#     wtd_mean_FusionHeat + gmean_FusionHeat + wtd_gmean_FusionHeat +
#     entropy_FusionHeat + wtd_entropy_FusionHeat + range_FusionHeat +
#     wtd_range_FusionHeat + std_FusionHeat + wtd_std_FusionHeat +
#     mean_ThermalConductivity + wtd_mean_ThermalConductivity +
#     gmean_ThermalConductivity + wtd_gmean_ThermalConductivity +
#     entropy_ThermalConductivity + wtd_entropy_ThermalConductivity +
#     range_ThermalConductivity + wtd_range_ThermalConductivity +
#     std_ThermalConductivity + wtd_std_ThermalConductivity + mean_Valence +
#     wtd_mean_Valence + gmean_Valence + wtd_gmean_Valence + entropy_Valence +
#     wtd_entropy_Valence + range_Valence + wtd_range_Valence +
#     std_Valence + wtd_std_Valence
#
#                                   Df Sum of Sq     RSS    AIC
# - wtd_range_Density                1        12 6554671 122665
# - wtd_mean_Density                 1        22 6554681 122665
# - wtd_std_ThermalConductivity      1        36 6554695 122665
# - wtd_entropy_ThermalConductivity  1       266 6554925 122665
# - gmean_atomic_radius              1       385 6555044 122666
# - wtd_std_fie                      1       393 6555052 122666
# - wtd_range_atomic_mass            1       429 6555088 122666
# - wtd_range_Valence                1       477 6555135 122666
# - wtd_entropy_atomic_mass          1       485 6555144 122666
# - wtd_std_atomic_mass              1       848 6555507 122667
# - entropy_ElectronAffinity         1       930 6555589 122668
# - std_FusionHeat                   1      1416 6556075 122669
# - wtd_mean_fie                     1      1653 6556312 122670
# - mean_ElectronAffinity            1      1717 6556376 122670
# - gmean_fie                        1      1831 6556490 122671
# - gmean_Density                    1      1878 6556537 122671
# - mean_fie                         1      1974 6556633 122671
# - gmean_ThermalConductivity        1      1987 6556646 122671
# - wtd_gmean_fie                    1      2089 6556748 122671
# - mean_ThermalConductivity         1      2312 6556971 122672
# - std_Valence                      1      2487 6557146 122673
# - mean_Valence                     1      2495 6557154 122673
# - mean_atomic_radius               1      2740 6557399 122673
# - wtd_std_Density                  1      2911 6557570 122674
# <none>                                         6554659 122675
# - wtd_mean_Valence                 1      3558 6558217 122676
# - std_atomic_radius                1      4073 6558732 122678
# - gmean_Valence                    1      4294 6558953 122679
# - wtd_std_atomic_radius            1      4417 6559076 122679
# - wtd_gmean_Density                1      4811 6559470 122680
# - wtd_gmean_Valence                1      5469 6560127 122682
# - gmean_ElectronAffinity           1      6168 6560827 122685
# - entropy_atomic_radius            1      6283 6560942 122685
# - entropy_Density                  1      6497 6561156 122686
# - number_of_elements               1      6761 6561420 122687
# - wtd_std_FusionHeat               1      7199 6561858 122688
# - range_FusionHeat                 1      9446 6564105 122695
# - entropy_ThermalConductivity      1      9732 6564391 122696
# - wtd_range_atomic_radius          1     10177 6564835 122698
# - entropy_fie                      1     10695 6565354 122699
# - wtd_range_fie                    1     10836 6565495 122700
# - entropy_Valence                  1     11343 6566002 122701
# - gmean_atomic_mass                1     11997 6566656 122703
# - range_ThermalConductivity        1     13142 6567801 122707
# - range_Valence                    1     13263 6567922 122708
# - wtd_gmean_atomic_mass            1     13580 6568239 122709
# - wtd_range_ElectronAffinity       1     13889 6568548 122710
# - std_ThermalConductivity          1     14297 6568956 122711
# - entropy_FusionHeat               1     15946 6570605 122716
# - range_Density                    1     16604 6571263 122718
# - wtd_entropy_Density              1     16686 6571345 122719
# - entropy_atomic_mass              1     18919 6573578 122726
# - wtd_entropy_atomic_radius        1     22069 6576728 122736
# - std_Density                      1     23587 6578246 122741
# - wtd_mean_atomic_mass             1     23818 6578477 122742
# - range_atomic_radius              1     23999 6578658 122742
# - std_fie                          1     24325 6578984 122743
# - gmean_FusionHeat                 1     24469 6579128 122744
# - wtd_range_FusionHeat             1     24494 6579153 122744
# - wtd_gmean_FusionHeat             1     24695 6579354 122745
# - std_atomic_mass                  1     24712 6579371 122745
# - mean_FusionHeat                  1     25767 6580426 122748
# - wtd_entropy_fie                  1     26440 6581099 122750
# - mean_Density                     1     27867 6582526 122755
# - wtd_entropy_ElectronAffinity     1     28914 6583573 122758
# - wtd_mean_FusionHeat              1     30846 6585505 122764
# - wtd_mean_ElectronAffinity        1     32432 6587091 122770
# - mean_atomic_mass                 1     32507 6587166 122770
# - range_fie                        1     35036 6589695 122778
# - wtd_gmean_ThermalConductivity    1     43789 6598448 122806
# - wtd_gmean_atomic_radius          1     45486 6600144 122812
# - wtd_entropy_Valence              1     49548 6604207 122825
# - wtd_gmean_ElectronAffinity       1     51213 6605872 122830
# - range_atomic_mass                1     51956 6606614 122832
# - wtd_std_Valence                  1     53322 6607981 122837
# - wtd_entropy_FusionHeat           1     54075 6608734 122839
# - wtd_mean_atomic_radius           1     56456 6611115 122847
# - wtd_std_ElectronAffinity         1     60624 6615283 122860
# - wtd_range_ThermalConductivity    1     61367 6616026 122863
# - wtd_mean_ThermalConductivity     1    108061 6662720 123012
# - range_ElectronAffinity           1    138826 6693485 123110
# - std_ElectronAffinity             1    141384 6696043 123118
#
# Step:  AIC=122664.6
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     wtd_entropy_atomic_mass + range_atomic_mass + wtd_range_atomic_mass +
#     std_atomic_mass + wtd_std_atomic_mass + mean_fie + wtd_mean_fie +
#     gmean_fie + wtd_gmean_fie + entropy_fie + wtd_entropy_fie +
#     range_fie + wtd_range_fie + std_fie + wtd_std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + gmean_atomic_radius + wtd_gmean_atomic_radius +
#     entropy_atomic_radius + wtd_entropy_atomic_radius + range_atomic_radius +
#     wtd_range_atomic_radius + std_atomic_radius + wtd_std_atomic_radius +
#     mean_Density + wtd_mean_Density + gmean_Density + wtd_gmean_Density +
#     entropy_Density + wtd_entropy_Density + range_Density + std_Density +
#     wtd_std_Density + mean_ElectronAffinity + wtd_mean_ElectronAffinity +
#     gmean_ElectronAffinity + wtd_gmean_ElectronAffinity + entropy_ElectronAffinity +
#     wtd_entropy_ElectronAffinity + range_ElectronAffinity + wtd_range_ElectronAffinity +
#     std_ElectronAffinity + wtd_std_ElectronAffinity + mean_FusionHeat +
#     wtd_mean_FusionHeat + gmean_FusionHeat + wtd_gmean_FusionHeat +
#     entropy_FusionHeat + wtd_entropy_FusionHeat + range_FusionHeat +
#     wtd_range_FusionHeat + std_FusionHeat + wtd_std_FusionHeat +
#     mean_ThermalConductivity + wtd_mean_ThermalConductivity +
#     gmean_ThermalConductivity + wtd_gmean_ThermalConductivity +
#     entropy_ThermalConductivity + wtd_entropy_ThermalConductivity +
#     range_ThermalConductivity + wtd_range_ThermalConductivity +
#     std_ThermalConductivity + wtd_std_ThermalConductivity + mean_Valence +
#     wtd_mean_Valence + gmean_Valence + wtd_gmean_Valence + entropy_Valence +
#     wtd_entropy_Valence + range_Valence + wtd_range_Valence +
#     std_Valence + wtd_std_Valence
#
#                                   Df Sum of Sq     RSS    AIC
# - wtd_std_ThermalConductivity      1        30 6554701 122655
# - wtd_mean_Density                 1        37 6554708 122655
# - wtd_entropy_ThermalConductivity  1       276 6554947 122656
# - gmean_atomic_radius              1       393 6555064 122656
# - wtd_std_fie                      1       402 6555073 122656
# - wtd_entropy_atomic_mass          1       476 6555147 122656
# - wtd_range_Valence                1       555 6555226 122656
# - wtd_range_atomic_mass            1       601 6555272 122657
# - wtd_std_atomic_mass              1       866 6555537 122657
# - entropy_ElectronAffinity         1       940 6555612 122658
# - std_FusionHeat                   1      1406 6556077 122659
# - wtd_mean_fie                     1      1641 6556312 122660
# - mean_ElectronAffinity            1      1712 6556384 122660
# - gmean_fie                        1      1819 6556490 122661
# - mean_fie                         1      1962 6556633 122661
# - gmean_ThermalConductivity        1      2014 6556685 122661
# - gmean_Density                    1      2022 6556693 122661
# - wtd_gmean_fie                    1      2077 6556748 122661
# - mean_ThermalConductivity         1      2311 6556982 122662
# - std_Valence                      1      2475 6557147 122663
# - mean_Valence                     1      2484 6557156 122663
# - mean_atomic_radius               1      2758 6557429 122664
# - wtd_std_Density                  1      2927 6557598 122664
# <none>                                         6554671 122665
# - wtd_mean_Valence                 1      3546 6558217 122666
# - std_atomic_radius                1      4062 6558733 122668
# - gmean_Valence                    1      4282 6558953 122669
# - wtd_std_atomic_radius            1      4495 6559166 122669
# - wtd_gmean_Density                1      4837 6559508 122670
# - wtd_gmean_Valence                1      5461 6560132 122672
# - gmean_ElectronAffinity           1      6161 6560832 122675
# - entropy_atomic_radius            1      6271 6560943 122675
# - entropy_Density                  1      6632 6561304 122676
# - number_of_elements               1      6749 6561420 122677
# - wtd_std_FusionHeat               1      7213 6561884 122678
# - range_FusionHeat                 1      9611 6564282 122686
# - entropy_ThermalConductivity      1      9720 6564391 122686
# - wtd_range_atomic_radius          1     10182 6564853 122688
# - entropy_fie                      1     10697 6565369 122689
# - wtd_range_fie                    1     10911 6565582 122690
# - entropy_Valence                  1     11340 6566011 122691
# - gmean_atomic_mass                1     12132 6566803 122694
# - range_Valence                    1     13261 6567932 122698
# - range_ThermalConductivity        1     13316 6567987 122698
# - wtd_gmean_atomic_mass            1     13744 6568415 122699
# - wtd_range_ElectronAffinity       1     13906 6568577 122700
# - std_ThermalConductivity          1     14300 6568972 122701
# - entropy_FusionHeat               1     16069 6570741 122707
# - range_Density                    1     16597 6571268 122708
# - entropy_atomic_mass              1     18963 6573634 122716
# - wtd_entropy_Density              1     19223 6573894 122717
# - wtd_entropy_atomic_radius        1     22156 6576827 122726
# - std_Density                      1     23776 6578447 122732
# - wtd_mean_atomic_mass             1     23830 6578501 122732
# - range_atomic_radius              1     23988 6578659 122732
# - std_fie                          1     24391 6579062 122734
# - gmean_FusionHeat                 1     24464 6579135 122734
# - wtd_gmean_FusionHeat             1     24703 6579374 122735
# - std_atomic_mass                  1     24704 6579375 122735
# - wtd_range_FusionHeat             1     25421 6580093 122737
# - mean_FusionHeat                  1     25824 6580495 122738
# - wtd_entropy_fie                  1     26997 6581668 122742
# - mean_Density                     1     28172 6582843 122746
# - wtd_entropy_ElectronAffinity     1     29190 6583861 122749
# - wtd_mean_FusionHeat              1     31166 6585837 122756
# - wtd_mean_ElectronAffinity        1     32441 6587112 122760
# - mean_atomic_mass                 1     32495 6587166 122760
# - range_fie                        1     35044 6589716 122768
# - wtd_gmean_ThermalConductivity    1     43856 6598527 122796
# - wtd_gmean_atomic_radius          1     45612 6600283 122802
# - wtd_entropy_Valence              1     50975 6605646 122819
# - wtd_gmean_ElectronAffinity       1     51246 6605917 122820
# - range_atomic_mass                1     51944 6606616 122823
# - wtd_std_Valence                  1     53418 6608089 122827
# - wtd_entropy_FusionHeat           1     54435 6609106 122831
# - wtd_mean_atomic_radius           1     56556 6611227 122837
# - wtd_std_ElectronAffinity         1     60684 6615355 122851
# - wtd_range_ThermalConductivity    1     63105 6617776 122858
# - wtd_mean_ThermalConductivity     1    108164 6662835 123003
# - range_ElectronAffinity           1    138959 6693630 123101
# - std_ElectronAffinity             1    141781 6696452 123110
#
# Step:  AIC=122654.8
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     wtd_entropy_atomic_mass + range_atomic_mass + wtd_range_atomic_mass +
#     std_atomic_mass + wtd_std_atomic_mass + mean_fie + wtd_mean_fie +
#     gmean_fie + wtd_gmean_fie + entropy_fie + wtd_entropy_fie +
#     range_fie + wtd_range_fie + std_fie + wtd_std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + gmean_atomic_radius + wtd_gmean_atomic_radius +
#     entropy_atomic_radius + wtd_entropy_atomic_radius + range_atomic_radius +
#     wtd_range_atomic_radius + std_atomic_radius + wtd_std_atomic_radius +
#     mean_Density + wtd_mean_Density + gmean_Density + wtd_gmean_Density +
#     entropy_Density + wtd_entropy_Density + range_Density + std_Density +
#     wtd_std_Density + mean_ElectronAffinity + wtd_mean_ElectronAffinity +
#     gmean_ElectronAffinity + wtd_gmean_ElectronAffinity + entropy_ElectronAffinity +
#     wtd_entropy_ElectronAffinity + range_ElectronAffinity + wtd_range_ElectronAffinity +
#     std_ElectronAffinity + wtd_std_ElectronAffinity + mean_FusionHeat +
#     wtd_mean_FusionHeat + gmean_FusionHeat + wtd_gmean_FusionHeat +
#     entropy_FusionHeat + wtd_entropy_FusionHeat + range_FusionHeat +
#     wtd_range_FusionHeat + std_FusionHeat + wtd_std_FusionHeat +
#     mean_ThermalConductivity + wtd_mean_ThermalConductivity +
#     gmean_ThermalConductivity + wtd_gmean_ThermalConductivity +
#     entropy_ThermalConductivity + wtd_entropy_ThermalConductivity +
#     range_ThermalConductivity + wtd_range_ThermalConductivity +
#     std_ThermalConductivity + mean_Valence + wtd_mean_Valence +
#     gmean_Valence + wtd_gmean_Valence + entropy_Valence + wtd_entropy_Valence +
#     range_Valence + wtd_range_Valence + std_Valence + wtd_std_Valence
#
#                                   Df Sum of Sq     RSS    AIC
# - wtd_mean_Density                 1        31 6554732 122645
# - gmean_atomic_radius              1       381 6555082 122646
# - wtd_std_fie                      1       388 6555089 122646
# - wtd_entropy_ThermalConductivity  1       438 6555139 122646
# - wtd_entropy_atomic_mass          1       509 6555210 122646
# - wtd_range_Valence                1       553 6555254 122647
# - wtd_range_atomic_mass            1       618 6555319 122647
# - wtd_std_atomic_mass              1       874 6555575 122648
# - entropy_ElectronAffinity         1       964 6555665 122648
# - std_FusionHeat                   1      1416 6556117 122649
# - wtd_mean_fie                     1      1699 6556400 122650
# - mean_ElectronAffinity            1      1720 6556421 122650
# - gmean_fie                        1      1831 6556532 122651
# - mean_fie                         1      1981 6556682 122651
# - gmean_Density                    1      2103 6556804 122652
# - wtd_gmean_fie                    1      2141 6556842 122652
# - std_Valence                      1      2503 6557204 122653
# - mean_ThermalConductivity         1      2523 6557223 122653
# - mean_Valence                     1      2530 6557231 122653
# - mean_atomic_radius               1      2732 6557433 122654
# <none>                                         6554701 122655
# - wtd_std_Density                  1      3169 6557870 122655
# - gmean_ThermalConductivity        1      3332 6558033 122656
# - wtd_mean_Valence                 1      3693 6558394 122657
# - std_atomic_radius                1      4103 6558804 122658
# - gmean_Valence                    1      4309 6559010 122659
# - wtd_std_atomic_radius            1      4476 6559177 122659
# - wtd_gmean_Density                1      4819 6559520 122660
# - wtd_gmean_Valence                1      5613 6560314 122663
# - gmean_ElectronAffinity           1      6224 6560925 122665
# - entropy_atomic_radius            1      6311 6561012 122665
# - number_of_elements               1      6835 6561536 122667
# - entropy_Density                  1      6873 6561574 122667
# - wtd_std_FusionHeat               1      7184 6561884 122668
# - range_FusionHeat                 1      9583 6564284 122676
# - entropy_ThermalConductivity      1     10210 6564911 122678
# - wtd_range_atomic_radius          1     10386 6565087 122678
# - entropy_fie                      1     10752 6565452 122680
# - wtd_range_fie                    1     10890 6565591 122680
# - entropy_Valence                  1     11401 6566102 122682
# - gmean_atomic_mass                1     12131 6566832 122684
# - range_Valence                    1     13303 6568004 122688
# - range_ThermalConductivity        1     13340 6568041 122688
# - wtd_gmean_atomic_mass            1     13718 6568419 122689
# - wtd_range_ElectronAffinity       1     13885 6568586 122690
# - entropy_FusionHeat               1     16085 6570786 122697
# - range_Density                    1     16611 6571312 122699
# - std_ThermalConductivity          1     16675 6571376 122699
# - entropy_atomic_mass              1     19094 6573795 122707
# - wtd_entropy_Density              1     20042 6574743 122710
# - wtd_entropy_atomic_radius        1     22885 6577586 122719
# - wtd_mean_atomic_mass             1     23809 6578510 122722
# - range_atomic_radius              1     24173 6578874 122723
# - std_Density                      1     24395 6579096 122724
# - std_fie                          1     24431 6579132 122724
# - gmean_FusionHeat                 1     24446 6579147 122724
# - std_atomic_mass                  1     24760 6579461 122725
# - wtd_gmean_FusionHeat             1     24802 6579503 122725
# - wtd_range_FusionHeat             1     25532 6580233 122727
# - mean_FusionHeat                  1     25795 6580496 122728
# - wtd_entropy_fie                  1     27349 6582050 122733
# - mean_Density                     1     28518 6583219 122737
# - wtd_entropy_ElectronAffinity     1     29336 6584036 122740
# - wtd_mean_FusionHeat              1     31231 6585932 122746
# - mean_atomic_mass                 1     32534 6587235 122750
# - wtd_mean_ElectronAffinity        1     32653 6587354 122750
# - range_fie                        1     35038 6589739 122758
# - wtd_gmean_atomic_radius          1     45697 6600398 122793
# - range_atomic_mass                1     51915 6606616 122813
# - wtd_gmean_ElectronAffinity       1     52042 6606743 122813
# - wtd_entropy_Valence              1     53228 6607929 122817
# - wtd_std_Valence                  1     54251 6608952 122820
# - wtd_entropy_FusionHeat           1     54413 6609114 122821
# - wtd_mean_atomic_radius           1     56696 6611397 122828
# - wtd_std_ElectronAffinity         1     60739 6615440 122841
# - wtd_range_ThermalConductivity    1     63356 6618057 122849
# - wtd_gmean_ThermalConductivity    1    106623 6661324 122988
# - range_ElectronAffinity           1    138950 6693651 123091
# - std_ElectronAffinity             1    141780 6696481 123100
# - wtd_mean_ThermalConductivity     1    192414 6747115 123260
#
# Step:  AIC=122644.9
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     wtd_entropy_atomic_mass + range_atomic_mass + wtd_range_atomic_mass +
#     std_atomic_mass + wtd_std_atomic_mass + mean_fie + wtd_mean_fie +
#     gmean_fie + wtd_gmean_fie + entropy_fie + wtd_entropy_fie +
#     range_fie + wtd_range_fie + std_fie + wtd_std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + gmean_atomic_radius + wtd_gmean_atomic_radius +
#     entropy_atomic_radius + wtd_entropy_atomic_radius + range_atomic_radius +
#     wtd_range_atomic_radius + std_atomic_radius + wtd_std_atomic_radius +
#     mean_Density + gmean_Density + wtd_gmean_Density + entropy_Density +
#     wtd_entropy_Density + range_Density + std_Density + wtd_std_Density +
#     mean_ElectronAffinity + wtd_mean_ElectronAffinity + gmean_ElectronAffinity +
#     wtd_gmean_ElectronAffinity + entropy_ElectronAffinity + wtd_entropy_ElectronAffinity +
#     range_ElectronAffinity + wtd_range_ElectronAffinity + std_ElectronAffinity +
#     wtd_std_ElectronAffinity + mean_FusionHeat + wtd_mean_FusionHeat +
#     gmean_FusionHeat + wtd_gmean_FusionHeat + entropy_FusionHeat +
#     wtd_entropy_FusionHeat + range_FusionHeat + wtd_range_FusionHeat +
#     std_FusionHeat + wtd_std_FusionHeat + mean_ThermalConductivity +
#     wtd_mean_ThermalConductivity + gmean_ThermalConductivity +
#     wtd_gmean_ThermalConductivity + entropy_ThermalConductivity +
#     wtd_entropy_ThermalConductivity + range_ThermalConductivity +
#     wtd_range_ThermalConductivity + std_ThermalConductivity +
#     mean_Valence + wtd_mean_Valence + gmean_Valence + wtd_gmean_Valence +
#     entropy_Valence + wtd_entropy_Valence + range_Valence + wtd_range_Valence +
#     std_Valence + wtd_std_Valence
#
#                                   Df Sum of Sq     RSS    AIC
# - gmean_atomic_radius              1       391 6555123 122636
# - wtd_entropy_ThermalConductivity  1       420 6555152 122636
# - wtd_std_fie                      1       457 6555189 122636
# - wtd_entropy_atomic_mass          1       493 6555225 122637
# - wtd_range_Valence                1       584 6555316 122637
# - wtd_range_atomic_mass            1       617 6555349 122637
# - entropy_ElectronAffinity         1       972 6555704 122638
# - wtd_std_atomic_mass              1      1019 6555751 122638
# - std_FusionHeat                   1      1423 6556155 122640
# - wtd_mean_fie                     1      1668 6556400 122640
# - mean_ElectronAffinity            1      1702 6556434 122640
# - gmean_fie                        1      1832 6556564 122641
# - mean_fie                         1      1981 6556713 122641
# - wtd_gmean_fie                    1      2112 6556844 122642
# - mean_ThermalConductivity         1      2528 6557260 122643
# - mean_Valence                     1      2604 6557336 122643
# - std_Valence                      1      2614 6557345 122643
# - mean_atomic_radius               1      2772 6557504 122644
# <none>                                         6554732 122645
# - gmean_ThermalConductivity        1      3375 6558106 122646
# - wtd_mean_Valence                 1      3745 6558477 122647
# - gmean_Density                    1      4064 6558796 122648
# - std_atomic_radius                1      4132 6558864 122648
# - wtd_std_atomic_radius            1      4447 6559179 122649
# - gmean_Valence                    1      4451 6559183 122649
# - wtd_std_Density                  1      4880 6559612 122651
# - wtd_gmean_Valence                1      5707 6560439 122653
# - gmean_ElectronAffinity           1      6193 6560925 122655
# - entropy_atomic_radius            1      6281 6561013 122655
# - entropy_Density                  1      6931 6561663 122657
# - number_of_elements               1      7121 6561852 122658
# - wtd_std_FusionHeat               1      7551 6562283 122659
# - range_FusionHeat                 1      9661 6564393 122666
# - entropy_ThermalConductivity      1     10360 6565091 122669
# - wtd_range_atomic_radius          1     10424 6565156 122669
# - entropy_fie                      1     10825 6565557 122670
# - wtd_range_fie                    1     11245 6565977 122671
# - entropy_Valence                  1     11473 6566205 122672
# - gmean_atomic_mass                1     12792 6567524 122676
# - range_Valence                    1     13298 6568030 122678
# - range_ThermalConductivity        1     13319 6568051 122678
# - wtd_range_ElectronAffinity       1     13941 6568673 122680
# - wtd_gmean_atomic_mass            1     15663 6570395 122686
# - entropy_FusionHeat               1     16135 6570866 122687
# - range_Density                    1     16588 6571320 122689
# - std_ThermalConductivity          1     16668 6571400 122689
# - wtd_gmean_Density                1     18957 6573688 122696
# - entropy_atomic_mass              1     19077 6573809 122697
# - wtd_entropy_Density              1     20060 6574792 122700
# - wtd_entropy_atomic_radius        1     23204 6577936 122710
# - range_atomic_radius              1     24143 6578875 122713
# - std_fie                          1     24430 6579162 122714
# - gmean_FusionHeat                 1     24672 6579404 122715
# - std_atomic_mass                  1     25445 6580177 122717
# - wtd_range_FusionHeat             1     25507 6580239 122718
# - mean_FusionHeat                  1     26006 6580738 122719
# - wtd_gmean_FusionHeat             1     26008 6580740 122719
# - std_Density                      1     26861 6581593 122722
# - wtd_entropy_fie                  1     27319 6582051 122723
# - wtd_mean_atomic_mass             1     28409 6583141 122727
# - wtd_entropy_ElectronAffinity     1     29377 6584109 122730
# - wtd_mean_FusionHeat              1     32559 6587291 122740
# - wtd_mean_ElectronAffinity        1     32626 6587357 122741
# - range_fie                        1     35249 6589981 122749
# - mean_atomic_mass                 1     35628 6590360 122750
# - wtd_gmean_atomic_radius          1     45723 6600454 122783
# - range_atomic_mass                1     51906 6606638 122803
# - wtd_gmean_ElectronAffinity       1     52057 6606789 122803
# - wtd_entropy_Valence              1     53696 6608428 122808
# - wtd_entropy_FusionHeat           1     54905 6609636 122812
# - wtd_std_Valence                  1     55479 6610211 122814
# - wtd_mean_atomic_radius           1     56702 6611434 122818
# - mean_Density                     1     58977 6613709 122825
# - wtd_std_ElectronAffinity         1     62888 6617620 122838
# - wtd_range_ThermalConductivity    1     65341 6620073 122846
# - wtd_gmean_ThermalConductivity    1    108342 6663074 122984
# - range_ElectronAffinity           1    141146 6695878 123088
# - std_ElectronAffinity             1    141803 6696535 123090
# - wtd_mean_ThermalConductivity     1    192612 6747343 123251
#
# Step:  AIC=122636.2
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     wtd_entropy_atomic_mass + range_atomic_mass + wtd_range_atomic_mass +
#     std_atomic_mass + wtd_std_atomic_mass + mean_fie + wtd_mean_fie +
#     gmean_fie + wtd_gmean_fie + entropy_fie + wtd_entropy_fie +
#     range_fie + wtd_range_fie + std_fie + wtd_std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + wtd_gmean_atomic_radius + entropy_atomic_radius +
#     wtd_entropy_atomic_radius + range_atomic_radius + wtd_range_atomic_radius +
#     std_atomic_radius + wtd_std_atomic_radius + mean_Density +
#     gmean_Density + wtd_gmean_Density + entropy_Density + wtd_entropy_Density +
#     range_Density + std_Density + wtd_std_Density + mean_ElectronAffinity +
#     wtd_mean_ElectronAffinity + gmean_ElectronAffinity + wtd_gmean_ElectronAffinity +
#     entropy_ElectronAffinity + wtd_entropy_ElectronAffinity +
#     range_ElectronAffinity + wtd_range_ElectronAffinity + std_ElectronAffinity +
#     wtd_std_ElectronAffinity + mean_FusionHeat + wtd_mean_FusionHeat +
#     gmean_FusionHeat + wtd_gmean_FusionHeat + entropy_FusionHeat +
#     wtd_entropy_FusionHeat + range_FusionHeat + wtd_range_FusionHeat +
#     std_FusionHeat + wtd_std_FusionHeat + mean_ThermalConductivity +
#     wtd_mean_ThermalConductivity + gmean_ThermalConductivity +
#     wtd_gmean_ThermalConductivity + entropy_ThermalConductivity +
#     wtd_entropy_ThermalConductivity + range_ThermalConductivity +
#     wtd_range_ThermalConductivity + std_ThermalConductivity +
#     mean_Valence + wtd_mean_Valence + gmean_Valence + wtd_gmean_Valence +
#     entropy_Valence + wtd_entropy_Valence + range_Valence + wtd_range_Valence +
#     std_Valence + wtd_std_Valence
#
#                                   Df Sum of Sq     RSS    AIC
# - wtd_entropy_ThermalConductivity  1       365 6555487 122627
# - wtd_std_fie                      1       458 6555580 122628
# - wtd_entropy_atomic_mass          1       487 6555609 122628
# - wtd_range_Valence                1       526 6555649 122628
# - wtd_range_atomic_mass            1       670 6555793 122628
# - wtd_std_atomic_mass              1       835 6555957 122629
# - entropy_ElectronAffinity         1       904 6556026 122629
# - std_FusionHeat                   1      1250 6556372 122630
# - wtd_mean_fie                     1      1411 6556533 122631
# - gmean_fie                        1      1515 6556638 122631
# - mean_fie                         1      1663 6556786 122632
# - wtd_gmean_fie                    1      1825 6556947 122632
# - mean_ElectronAffinity            1      1932 6557054 122633
# - mean_ThermalConductivity         1      2475 6557598 122634
# - std_Valence                      1      2547 6557669 122635
# - mean_Valence                     1      2552 6557675 122635
# <none>                                         6555123 122636
# - gmean_ThermalConductivity        1      3549 6558672 122638
# - wtd_mean_Valence                 1      3695 6558817 122638
# - gmean_Density                    1      4215 6559338 122640
# - gmean_Valence                    1      4373 6559496 122640
# - wtd_std_Density                  1      4605 6559727 122641
# - wtd_std_atomic_radius            1      5261 6560383 122643
# - wtd_gmean_Valence                1      5634 6560757 122645
# - entropy_atomic_radius            1      6217 6561339 122646
# - gmean_ElectronAffinity           1      6636 6561759 122648
# - entropy_Density                  1      6789 6561912 122648
# - number_of_elements               1      7068 6562191 122649
# - wtd_std_FusionHeat               1      7232 6562354 122650
# - range_FusionHeat                 1     10028 6565151 122659
# - wtd_range_atomic_radius          1     10325 6565447 122660
# - entropy_fie                      1     10525 6565647 122660
# - entropy_ThermalConductivity      1     10570 6565693 122661
# - wtd_range_fie                    1     10955 6566077 122662
# - entropy_Valence                  1     11208 6566331 122663
# - std_atomic_radius                1     11280 6566403 122663
# - gmean_atomic_mass                1     12402 6567524 122666
# - range_Valence                    1     13334 6568457 122669
# - range_ThermalConductivity        1     13536 6568659 122670
# - wtd_range_ElectronAffinity       1     14362 6569484 122673
# - wtd_gmean_atomic_mass            1     15275 6570398 122676
# - entropy_FusionHeat               1     16049 6571172 122678
# - range_Density                    1     16871 6571994 122681
# - std_ThermalConductivity          1     16878 6572001 122681
# - wtd_gmean_Density                1     18975 6574097 122688
# - entropy_atomic_mass              1     19258 6574380 122689
# - wtd_entropy_Density              1     19687 6574810 122690
# - wtd_entropy_atomic_radius        1     23065 6578188 122701
# - gmean_FusionHeat                 1     24303 6579425 122705
# - std_fie                          1     24326 6579449 122705
# - std_atomic_mass                  1     25056 6580178 122707
# - wtd_range_FusionHeat             1     25270 6580393 122708
# - wtd_gmean_FusionHeat             1     25618 6580740 122709
# - mean_FusionHeat                  1     25642 6580765 122709
# - range_atomic_radius              1     25700 6580823 122709
# - wtd_entropy_fie                  1     26928 6582051 122713
# - std_Density                      1     26950 6582072 122713
# - wtd_mean_atomic_mass             1     28026 6583148 122717
# - wtd_entropy_ElectronAffinity     1     29000 6584123 122720
# - wtd_mean_FusionHeat              1     32171 6587294 122730
# - wtd_mean_ElectronAffinity        1     34877 6589999 122739
# - range_fie                        1     35135 6590258 122740
# - mean_atomic_mass                 1     35355 6590477 122741
# - mean_atomic_radius               1     40931 6596054 122759
# - range_atomic_mass                1     51698 6606821 122793
# - wtd_entropy_Valence              1     53638 6608761 122800
# - wtd_entropy_FusionHeat           1     54530 6609653 122802
# - wtd_gmean_ElectronAffinity       1     55407 6610529 122805
# - wtd_std_Valence                  1     55536 6610659 122806
# - mean_Density                     1     60388 6615511 122821
# - wtd_std_ElectronAffinity         1     64101 6619223 122833
# - wtd_range_ThermalConductivity    1     65014 6620136 122836
# - wtd_gmean_atomic_radius          1     95206 6650328 122933
# - wtd_gmean_ThermalConductivity    1    110267 6665390 122981
# - wtd_mean_atomic_radius           1    110670 6665792 122982
# - range_ElectronAffinity           1    141844 6696967 123081
# - std_ElectronAffinity             1    143482 6698605 123087
# - wtd_mean_ThermalConductivity     1    193926 6749048 123246
#
# Step:  AIC=122627.4
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     wtd_entropy_atomic_mass + range_atomic_mass + wtd_range_atomic_mass +
#     std_atomic_mass + wtd_std_atomic_mass + mean_fie + wtd_mean_fie +
#     gmean_fie + wtd_gmean_fie + entropy_fie + wtd_entropy_fie +
#     range_fie + wtd_range_fie + std_fie + wtd_std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + wtd_gmean_atomic_radius + entropy_atomic_radius +
#     wtd_entropy_atomic_radius + range_atomic_radius + wtd_range_atomic_radius +
#     std_atomic_radius + wtd_std_atomic_radius + mean_Density +
#     gmean_Density + wtd_gmean_Density + entropy_Density + wtd_entropy_Density +
#     range_Density + std_Density + wtd_std_Density + mean_ElectronAffinity +
#     wtd_mean_ElectronAffinity + gmean_ElectronAffinity + wtd_gmean_ElectronAffinity +
#     entropy_ElectronAffinity + wtd_entropy_ElectronAffinity +
#     range_ElectronAffinity + wtd_range_ElectronAffinity + std_ElectronAffinity +
#     wtd_std_ElectronAffinity + mean_FusionHeat + wtd_mean_FusionHeat +
#     gmean_FusionHeat + wtd_gmean_FusionHeat + entropy_FusionHeat +
#     wtd_entropy_FusionHeat + range_FusionHeat + wtd_range_FusionHeat +
#     std_FusionHeat + wtd_std_FusionHeat + mean_ThermalConductivity +
#     wtd_mean_ThermalConductivity + gmean_ThermalConductivity +
#     wtd_gmean_ThermalConductivity + entropy_ThermalConductivity +
#     range_ThermalConductivity + wtd_range_ThermalConductivity +
#     std_ThermalConductivity + mean_Valence + wtd_mean_Valence +
#     gmean_Valence + wtd_gmean_Valence + entropy_Valence + wtd_entropy_Valence +
#     range_Valence + wtd_range_Valence + std_Valence + wtd_std_Valence
#
#                                 Df Sum of Sq     RSS    AIC
# - wtd_entropy_atomic_mass        1       385 6555872 122619
# - wtd_std_fie                    1       466 6555953 122619
# - wtd_range_Valence              1       531 6556018 122619
# - wtd_range_atomic_mass          1       632 6556119 122620
# - wtd_std_atomic_mass            1       787 6556274 122620
# - entropy_ElectronAffinity       1       818 6556305 122620
# - std_FusionHeat                 1      1290 6556778 122622
# - wtd_mean_fie                   1      1407 6556895 122622
# - gmean_fie                      1      1516 6557003 122622
# - mean_fie                       1      1659 6557146 122623
# - wtd_gmean_fie                  1      1825 6557312 122623
# - mean_ElectronAffinity          1      2174 6557662 122625
# - mean_Valence                   1      2436 6557923 122625
# - std_Valence                    1      2476 6557963 122625
# - mean_ThermalConductivity       1      2739 6558226 122626
# <none>                                       6555487 122627
# - gmean_ThermalConductivity      1      3404 6558891 122629
# - wtd_mean_Valence               1      3564 6559051 122629
# - gmean_Valence                  1      4245 6559733 122631
# - gmean_Density                  1      4446 6559933 122632
# - wtd_std_Density                1      4571 6560058 122632
# - wtd_gmean_Valence              1      5484 6560971 122635
# - wtd_std_atomic_radius          1      5539 6561026 122635
# - entropy_atomic_radius          1      6424 6561911 122638
# - entropy_Density                1      6467 6561954 122638
# - number_of_elements             1      7119 6562606 122641
# - gmean_ElectronAffinity         1      7275 6562762 122641
# - wtd_std_FusionHeat             1      7309 6562797 122641
# - range_FusionHeat               1      9858 6565345 122649
# - wtd_range_atomic_radius        1     10144 6565631 122650
# - entropy_fie                    1     10918 6566405 122653
# - std_atomic_radius              1     11012 6566499 122653
# - entropy_Valence                1     11142 6566629 122654
# - wtd_range_fie                  1     11503 6566990 122655
# - gmean_atomic_mass              1     12618 6568105 122658
# - range_Valence                  1     13469 6568956 122661
# - wtd_range_ElectronAffinity     1     14308 6569795 122664
# - wtd_gmean_atomic_mass          1     15371 6570858 122667
# - range_ThermalConductivity      1     15435 6570922 122667
# - entropy_FusionHeat             1     15742 6571229 122668
# - range_Density                  1     16977 6572464 122672
# - entropy_ThermalConductivity    1     18649 6574137 122678
# - wtd_gmean_Density              1     18824 6574311 122678
# - entropy_atomic_mass            1     18909 6574396 122679
# - wtd_entropy_Density            1     19334 6574821 122680
# - std_ThermalConductivity        1     20630 6576118 122684
# - std_fie                        1     24480 6579967 122697
# - std_atomic_mass                1     24732 6580219 122698
# - gmean_FusionHeat               1     24846 6580333 122698
# - wtd_range_FusionHeat           1     25040 6580527 122699
# - wtd_entropy_atomic_radius      1     25519 6581006 122700
# - range_atomic_radius            1     25585 6581073 122700
# - mean_FusionHeat                1     25903 6581391 122701
# - wtd_gmean_FusionHeat           1     25927 6581414 122701
# - std_Density                    1     26941 6582428 122705
# - wtd_entropy_fie                1     27482 6582969 122706
# - wtd_mean_atomic_mass           1     28110 6583597 122708
# - wtd_entropy_ElectronAffinity   1     28849 6584336 122711
# - wtd_mean_FusionHeat            1     32295 6587782 122722
# - range_fie                      1     35412 6590899 122732
# - mean_atomic_mass               1     35723 6591210 122733
# - wtd_mean_ElectronAffinity      1     36275 6591763 122735
# - mean_atomic_radius             1     45060 6600547 122763
# - range_atomic_mass              1     51354 6606841 122783
# - wtd_entropy_Valence            1     54077 6609564 122792
# - wtd_entropy_FusionHeat         1     54288 6609776 122793
# - wtd_std_Valence                1     55281 6610768 122796
# - wtd_gmean_ElectronAffinity     1     58085 6613573 122805
# - mean_Density                   1     61398 6616885 122816
# - wtd_std_ElectronAffinity       1     65701 6621188 122830
# - wtd_range_ThermalConductivity  1     84685 6640172 122890
# - wtd_gmean_atomic_radius        1     96023 6651510 122927
# - wtd_gmean_ThermalConductivity  1    110754 6666241 122974
# - wtd_mean_atomic_radius         1    112538 6668025 122979
# - range_ElectronAffinity         1    141659 6697146 123072
# - std_ElectronAffinity           1    143972 6699460 123079
# - wtd_mean_ThermalConductivity   1    195425 6750913 123242
#
# Step:  AIC=122618.7
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     range_atomic_mass + wtd_range_atomic_mass + std_atomic_mass +
#     wtd_std_atomic_mass + mean_fie + wtd_mean_fie + gmean_fie +
#     wtd_gmean_fie + entropy_fie + wtd_entropy_fie + range_fie +
#     wtd_range_fie + std_fie + wtd_std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + wtd_gmean_atomic_radius + entropy_atomic_radius +
#     wtd_entropy_atomic_radius + range_atomic_radius + wtd_range_atomic_radius +
#     std_atomic_radius + wtd_std_atomic_radius + mean_Density +
#     gmean_Density + wtd_gmean_Density + entropy_Density + wtd_entropy_Density +
#     range_Density + std_Density + wtd_std_Density + mean_ElectronAffinity +
#     wtd_mean_ElectronAffinity + gmean_ElectronAffinity + wtd_gmean_ElectronAffinity +
#     entropy_ElectronAffinity + wtd_entropy_ElectronAffinity +
#     range_ElectronAffinity + wtd_range_ElectronAffinity + std_ElectronAffinity +
#     wtd_std_ElectronAffinity + mean_FusionHeat + wtd_mean_FusionHeat +
#     gmean_FusionHeat + wtd_gmean_FusionHeat + entropy_FusionHeat +
#     wtd_entropy_FusionHeat + range_FusionHeat + wtd_range_FusionHeat +
#     std_FusionHeat + wtd_std_FusionHeat + mean_ThermalConductivity +
#     wtd_mean_ThermalConductivity + gmean_ThermalConductivity +
#     wtd_gmean_ThermalConductivity + entropy_ThermalConductivity +
#     range_ThermalConductivity + wtd_range_ThermalConductivity +
#     std_ThermalConductivity + mean_Valence + wtd_mean_Valence +
#     gmean_Valence + wtd_gmean_Valence + entropy_Valence + wtd_entropy_Valence +
#     range_Valence + wtd_range_Valence + std_Valence + wtd_std_Valence
#
#                                 Df Sum of Sq     RSS    AIC
# - wtd_range_atomic_mass          1       386 6556258 122610
# - wtd_range_Valence              1       452 6556325 122610
# - wtd_std_fie                    1       462 6556334 122610
# - wtd_std_atomic_mass            1       638 6556510 122611
# - entropy_ElectronAffinity       1       744 6556616 122611
# - std_FusionHeat                 1      1229 6557101 122613
# - wtd_mean_fie                   1      1414 6557286 122613
# - gmean_fie                      1      1492 6557364 122614
# - mean_fie                       1      1631 6557503 122614
# - wtd_gmean_fie                  1      1841 6557714 122615
# - mean_ElectronAffinity          1      2174 6558046 122616
# - mean_Valence                   1      2340 6558212 122616
# - std_Valence                    1      2608 6558480 122617
# - mean_ThermalConductivity       1      2860 6558732 122618
# <none>                                       6555872 122619
# - gmean_ThermalConductivity      1      3210 6559082 122619
# - wtd_mean_Valence               1      3508 6559380 122620
# - gmean_Valence                  1      4127 6559999 122622
# - wtd_std_Density                1      4208 6560080 122622
# - gmean_Density                  1      4280 6560152 122623
# - wtd_gmean_Valence              1      5433 6561305 122626
# - wtd_std_atomic_radius          1      5517 6561389 122627
# - entropy_atomic_radius          1      6104 6561976 122629
# - entropy_Density                1      6161 6562033 122629
# - wtd_std_FusionHeat             1      7019 6562891 122632
# - number_of_elements             1      7332 6563204 122633
# - gmean_ElectronAffinity         1      7346 6563218 122633
# - wtd_range_atomic_radius        1      9780 6565652 122640
# - range_FusionHeat               1     10004 6565876 122641
# - entropy_fie                    1     10871 6566743 122644
# - std_atomic_radius              1     11173 6567045 122645
# - wtd_range_fie                  1     11508 6567380 122646
# - entropy_Valence                1     11648 6567520 122646
# - range_Valence                  1     13294 6569166 122652
# - gmean_atomic_mass              1     13574 6569446 122653
# - wtd_range_ElectronAffinity     1     14934 6570806 122657
# - range_ThermalConductivity      1     15185 6571057 122658
# - entropy_FusionHeat             1     15762 6571634 122660
# - range_Density                  1     16842 6572714 122663
# - wtd_gmean_atomic_mass          1     17302 6573174 122665
# - entropy_ThermalConductivity    1     19069 6574941 122671
# - wtd_gmean_Density              1     19750 6575622 122673
# - entropy_atomic_mass            1     20000 6575872 122674
# - std_ThermalConductivity        1     20354 6576226 122675
# - wtd_entropy_Density            1     20663 6576535 122676
# - std_atomic_mass                1     24455 6580327 122688
# - std_fie                        1     24784 6580656 122689
# - wtd_range_FusionHeat           1     24939 6580811 122689
# - gmean_FusionHeat               1     25148 6581020 122690
# - range_atomic_radius            1     25527 6581399 122691
# - wtd_gmean_FusionHeat           1     25919 6581791 122693
# - mean_FusionHeat                1     26017 6581889 122693
# - std_Density                    1     26564 6582436 122695
# - wtd_entropy_fie                1     27139 6583011 122697
# - wtd_entropy_ElectronAffinity   1     28542 6584414 122701
# - wtd_mean_FusionHeat            1     32154 6588026 122713
# - wtd_mean_atomic_mass           1     32243 6588115 122713
# - range_fie                      1     35733 6591605 122724
# - wtd_mean_ElectronAffinity      1     36491 6592363 122727
# - mean_atomic_mass               1     39890 6595762 122738
# - wtd_entropy_atomic_radius      1     44710 6600582 122753
# - mean_atomic_radius             1     46200 6602072 122758
# - range_atomic_mass              1     50977 6606849 122773
# - wtd_entropy_Valence            1     53919 6609791 122783
# - wtd_entropy_FusionHeat         1     54430 6610302 122785
# - wtd_std_Valence                1     55990 6611862 122790
# - wtd_gmean_ElectronAffinity     1     58495 6614367 122798
# - mean_Density                   1     61881 6617754 122809
# - wtd_std_ElectronAffinity       1     65316 6621189 122820
# - wtd_range_ThermalConductivity  1     84740 6640612 122882
# - wtd_gmean_atomic_radius        1     97274 6653146 122922
# - wtd_gmean_ThermalConductivity  1    112789 6668661 122971
# - wtd_mean_atomic_radius         1    114113 6669985 122976
# - range_ElectronAffinity         1    141277 6697149 123062
# - std_ElectronAffinity           1    143588 6699460 123069
# - wtd_mean_ThermalConductivity   1    196079 6751951 123235
#
# Step:  AIC=122610
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     range_atomic_mass + std_atomic_mass + wtd_std_atomic_mass +
#     mean_fie + wtd_mean_fie + gmean_fie + wtd_gmean_fie + entropy_fie +
#     wtd_entropy_fie + range_fie + wtd_range_fie + std_fie + wtd_std_fie +
#     mean_atomic_radius + wtd_mean_atomic_radius + wtd_gmean_atomic_radius +
#     entropy_atomic_radius + wtd_entropy_atomic_radius + range_atomic_radius +
#     wtd_range_atomic_radius + std_atomic_radius + wtd_std_atomic_radius +
#     mean_Density + gmean_Density + wtd_gmean_Density + entropy_Density +
#     wtd_entropy_Density + range_Density + std_Density + wtd_std_Density +
# ...
#     range_Density + std_Density + wtd_std_Density + wtd_mean_ElectronAffinity +
#     gmean_ElectronAffinity + wtd_gmean_ElectronAffinity + wtd_entropy_ElectronAffinity +
#     range_ElectronAffinity + wtd_range_ElectronAffinity + std_ElectronAffinity +
#     wtd_std_ElectronAffinity + mean_FusionHeat + wtd_mean_FusionHeat +
#     gmean_FusionHeat + wtd_gmean_FusionHeat + entropy_FusionHeat +
#     wtd_entropy_FusionHeat + range_FusionHeat + wtd_range_FusionHeat +
#     wtd_std_FusionHeat + mean_ThermalConductivity + wtd_mean_ThermalConductivity +
#     gmean_ThermalConductivity + wtd_gmean_ThermalConductivity +
#     entropy_ThermalConductivity + range_ThermalConductivity +
#     wtd_range_ThermalConductivity + std_ThermalConductivity +
#     gmean_Valence + wtd_gmean_Valence + entropy_Valence + wtd_entropy_Valence +
#     range_Valence + wtd_std_Valence
#
#                                 Df Sum of Sq     RSS    AIC
# - gmean_ThermalConductivity      1      2600 6568286 122549
# - wtd_std_Density                1      3037 6568723 122551
# <none>                                       6565686 122551
# - gmean_Density                  1      3947 6569633 122554
# - mean_fie                       1      4857 6570543 122557
# - gmean_fie                      1      4921 6570607 122557
# - mean_ThermalConductivity       1      4944 6570630 122557
# - entropy_atomic_radius          1      4958 6570644 122557
# - wtd_std_FusionHeat             1      5783 6571469 122560
# - wtd_std_atomic_radius          1      5885 6571571 122560
# - entropy_Density                1      6527 6572213 122562
# - number_of_elements             1      7798 6573484 122566
# - entropy_fie                    1     11156 6576842 122577
# - wtd_range_fie                  1     12436 6578122 122581
# - wtd_mean_fie                   1     12636 6578322 122582
# - std_atomic_radius              1     12690 6578376 122582
# - wtd_range_atomic_radius        1     14280 6579966 122587
# - wtd_gmean_fie                  1     15529 6581215 122591
# - wtd_range_ElectronAffinity     1     15613 6581298 122591
# - gmean_Valence                  1     15839 6581525 122592
# - gmean_atomic_mass              1     16379 6582065 122594
# - range_Density                  1     16381 6582067 122594
# - entropy_FusionHeat             1     16514 6582200 122594
# - range_ThermalConductivity      1     17539 6583225 122598
# - gmean_ElectronAffinity         1     19065 6584751 122603
# - entropy_ThermalConductivity    1     20209 6585895 122606
# - wtd_gmean_Valence              1     20386 6586072 122607
# - entropy_atomic_mass            1     21185 6586871 122609
# - wtd_entropy_Density            1     22044 6587730 122612
# - entropy_Valence                1     23692 6589378 122618
# - std_ThermalConductivity        1     23700 6589386 122618
# - std_Density                    1     24048 6589734 122619
# - wtd_gmean_Density              1     24520 6590206 122620
# - wtd_gmean_FusionHeat           1     25708 6591393 122624
# - range_atomic_radius            1     26771 6592456 122627
# - wtd_range_FusionHeat           1     28072 6593758 122632
# - gmean_FusionHeat               1     28170 6593856 122632
# - wtd_gmean_atomic_mass          1     30985 6596670 122641
# - mean_FusionHeat                1     33028 6598714 122648
# - std_atomic_mass                1     35573 6601259 122656
# - wtd_mean_FusionHeat            1     35948 6601634 122657
# - range_fie                      1     38155 6603841 122664
# - wtd_entropy_ElectronAffinity   1     38644 6604330 122666
# - wtd_entropy_fie                1     38758 6604444 122666
# - range_FusionHeat               1     45249 6610935 122687
# - range_atomic_mass              1     50121 6615807 122703
# - wtd_mean_ElectronAffinity      1     53103 6618789 122712
# - mean_atomic_radius             1     54169 6619855 122716
# - mean_atomic_mass               1     54673 6620359 122717
# - std_fie                        1     55609 6621294 122720
# - wtd_entropy_FusionHeat         1     60526 6626212 122736
# - mean_Density                   1     61495 6627181 122739
# - wtd_entropy_atomic_radius      1     64806 6630492 122750
# - range_Valence                  1     65069 6630754 122751
# - wtd_mean_atomic_mass           1     74503 6640189 122781
# - wtd_std_ElectronAffinity       1     77653 6643339 122791
# - wtd_gmean_ElectronAffinity     1     78169 6643855 122793
# - wtd_range_ThermalConductivity  1     93919 6659605 122843
# - wtd_gmean_atomic_radius        1    108866 6674552 122891
# - wtd_entropy_Valence            1    125566 6691252 122944
# - wtd_gmean_ThermalConductivity  1    126912 6692598 122948
# - wtd_mean_atomic_radius         1    128845 6694531 122954
# - range_ElectronAffinity         1    156610 6722296 123042
# - wtd_std_Valence                1    158558 6724243 123048
# - std_ElectronAffinity           1    192055 6757741 123154
# - wtd_mean_ThermalConductivity   1    224061 6789747 123254
#
# Step:  AIC=122549.3
# critical_temp ~ number_of_elements + mean_atomic_mass + wtd_mean_atomic_mass +
#     gmean_atomic_mass + wtd_gmean_atomic_mass + entropy_atomic_mass +
#     range_atomic_mass + std_atomic_mass + mean_fie + wtd_mean_fie +
#     gmean_fie + wtd_gmean_fie + entropy_fie + wtd_entropy_fie +
#     range_fie + wtd_range_fie + std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + wtd_gmean_atomic_radius + entropy_atomic_radius +
#     wtd_entropy_atomic_radius + range_atomic_radius + wtd_range_atomic_radius +
#     std_atomic_radius + wtd_std_atomic_radius + mean_Density +
#     gmean_Density + wtd_gmean_Density + entropy_Density + wtd_entropy_Density +
#     range_Density + std_Density + wtd_std_Density + wtd_mean_ElectronAffinity +
#     gmean_ElectronAffinity + wtd_gmean_ElectronAffinity + wtd_entropy_ElectronAffinity +
#     range_ElectronAffinity + wtd_range_ElectronAffinity + std_ElectronAffinity +
#     wtd_std_ElectronAffinity + mean_FusionHeat + wtd_mean_FusionHeat +
#     gmean_FusionHeat + wtd_gmean_FusionHeat + entropy_FusionHeat +
#     wtd_entropy_FusionHeat + range_FusionHeat + wtd_range_FusionHeat +
#     wtd_std_FusionHeat + mean_ThermalConductivity + wtd_mean_ThermalConductivity +
#     wtd_gmean_ThermalConductivity + entropy_ThermalConductivity +
#     range_ThermalConductivity + wtd_range_ThermalConductivity +
#     std_ThermalConductivity + gmean_Valence + wtd_gmean_Valence +
#     entropy_Valence + wtd_entropy_Valence + range_Valence + wtd_std_Valence
#
#                                 Df Sum of Sq     RSS    AIC
# <none>                                       6568286 122549
# - wtd_std_Density                1      3298 6571584 122550
# - gmean_Density                  1      3675 6571961 122551
# - entropy_atomic_radius          1      4535 6572820 122554
# - gmean_fie                      1      4633 6572919 122554
# - mean_fie                       1      4670 6572956 122554
# - entropy_Density                1      5327 6573613 122557
# - wtd_std_FusionHeat             1      5721 6574007 122558
# - wtd_std_atomic_radius          1      5854 6574139 122558
# - number_of_elements             1      7645 6575931 122564
# - entropy_fie                    1     10419 6578705 122573
# - wtd_mean_fie                   1     12112 6580398 122579
# - wtd_range_fie                  1     12579 6580865 122580
# - std_atomic_radius              1     13497 6581783 122583
# - wtd_range_ElectronAffinity     1     14431 6582716 122586
# - wtd_range_atomic_radius        1     14500 6582785 122586
# - wtd_gmean_fie                  1     14871 6583156 122587
# - gmean_atomic_mass              1     14983 6583269 122588
# - gmean_Valence                  1     15990 6584276 122591
# - range_Density                  1     16352 6584638 122592
# - entropy_FusionHeat             1     17617 6585903 122596
# - gmean_ElectronAffinity         1     18386 6586671 122599
# - wtd_gmean_Valence              1     19323 6587609 122602
# - range_ThermalConductivity      1     19870 6588156 122604
# - wtd_entropy_Density            1     20083 6588368 122604
# - entropy_atomic_mass            1     21380 6589666 122608
# - mean_ThermalConductivity       1     23077 6591362 122614
# - entropy_Valence                1     23303 6591589 122615
# - std_Density                    1     23919 6592205 122617
# - wtd_gmean_Density              1     25492 6593777 122622
# - wtd_gmean_FusionHeat           1     25554 6593839 122622
# - wtd_range_FusionHeat           1     26041 6594327 122624
# - wtd_gmean_atomic_mass          1     28987 6597273 122633
# - gmean_FusionHeat               1     29193 6597479 122634
# - range_atomic_radius            1     29261 6597547 122634
# - entropy_ThermalConductivity    1     31477 6599763 122641
# - mean_FusionHeat                1     32926 6601211 122646
# - std_ThermalConductivity        1     34758 6603044 122652
# - wtd_mean_FusionHeat            1     34936 6603222 122652
# - std_atomic_mass                1     35820 6604106 122655
# - wtd_entropy_ElectronAffinity   1     36778 6605064 122658
# - wtd_entropy_fie                1     37211 6605497 122659
# - range_fie                      1     37424 6605710 122660
# - range_FusionHeat               1     45565 6613851 122686
# - range_atomic_mass              1     51350 6619636 122705
# - mean_atomic_mass               1     52513 6620798 122709
# - mean_atomic_radius             1     52742 6621028 122709
# - std_fie                        1     54162 6622448 122714
# - wtd_mean_ElectronAffinity      1     56407 6624693 122721
# - wtd_entropy_FusionHeat         1     60686 6628972 122735
# - mean_Density                   1     61994 6630280 122739
# - wtd_entropy_atomic_radius      1     62469 6630755 122741
# - range_Valence                  1     63869 6632155 122745
# - wtd_mean_atomic_mass           1     71974 6640260 122771
# - wtd_std_ElectronAffinity       1     77306 6645591 122788
# - wtd_gmean_ElectronAffinity     1     82146 6650432 122804
# - wtd_range_ThermalConductivity  1     91687 6659973 122834
# - wtd_gmean_atomic_radius        1    106429 6674715 122881
# - wtd_entropy_Valence            1    123632 6691918 122936
# - wtd_mean_atomic_radius         1    126269 6694555 122944
# - range_ElectronAffinity         1    155843 6724129 123038
# - wtd_std_Valence                1    156089 6724375 123039
# - std_ElectronAffinity           1    189877 6758163 123145
# - wtd_gmean_ThermalConductivity  1    240294 6808579 123303
# - wtd_mean_ThermalConductivity   1    244430 6812716 123316
# Call:
# lm(formula = critical_temp ~ number_of_elements + mean_atomic_mass +
#     wtd_mean_atomic_mass + gmean_atomic_mass + wtd_gmean_atomic_mass +
#     entropy_atomic_mass + range_atomic_mass + std_atomic_mass +
#     mean_fie + wtd_mean_fie + gmean_fie + wtd_gmean_fie + entropy_fie +
#     wtd_entropy_fie + range_fie + wtd_range_fie + std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + wtd_gmean_atomic_radius + entropy_atomic_radius +
#     wtd_entropy_atomic_radius + range_atomic_radius + wtd_range_atomic_radius +
#     std_atomic_radius + wtd_std_atomic_radius + mean_Density +
#     gmean_Density + wtd_gmean_Density + entropy_Density + wtd_entropy_Density +
#     range_Density + std_Density + wtd_std_Density + wtd_mean_ElectronAffinity +
#     gmean_ElectronAffinity + wtd_gmean_ElectronAffinity + wtd_entropy_ElectronAffinity +
#     range_ElectronAffinity + wtd_range_ElectronAffinity + std_ElectronAffinity +
#     wtd_std_ElectronAffinity + mean_FusionHeat + wtd_mean_FusionHeat +
#     gmean_FusionHeat + wtd_gmean_FusionHeat + entropy_FusionHeat +
#     wtd_entropy_FusionHeat + range_FusionHeat + wtd_range_FusionHeat +
#     wtd_std_FusionHeat + mean_ThermalConductivity + wtd_mean_ThermalConductivity +
#     wtd_gmean_ThermalConductivity + entropy_ThermalConductivity +
#     range_ThermalConductivity + wtd_range_ThermalConductivity +
#     std_ThermalConductivity + gmean_Valence + wtd_gmean_Valence +
#     entropy_Valence + wtd_entropy_Valence + range_Valence + wtd_std_Valence,
#     data = supercon_data)
#
# Coefficients:
#                   (Intercept)             number_of_elements
#                    -1.861e+01                     -3.560e+00
#              mean_atomic_mass           wtd_mean_atomic_mass
#                     7.717e-01                     -7.805e-01
#             gmean_atomic_mass          wtd_gmean_atomic_mass
#                    -4.370e-01                      5.296e-01
#           entropy_atomic_mass              range_atomic_mass
#                    -3.365e+01                      2.077e-01
#               std_atomic_mass                       mean_fie
#                    -4.709e-01                      1.655e-01
#                  wtd_mean_fie                      gmean_fie
#                    -2.170e-01                     -1.630e-01
#                 wtd_gmean_fie                    entropy_fie
#                     2.400e-01                     -1.037e+02
#               wtd_entropy_fie                      range_fie
#                     4.357e+01                      6.865e-02
#                 wtd_range_fie                        std_fie
#                     1.990e-02                     -2.104e-01
#            mean_atomic_radius         wtd_mean_atomic_radius
#                    -3.499e-01                      3.055e+00
#       wtd_gmean_atomic_radius          entropy_atomic_radius
#                    -2.653e+00                      6.245e+01
#     wtd_entropy_atomic_radius            range_atomic_radius
#                     5.158e+01                      2.073e-01
#       wtd_range_atomic_radius              std_atomic_radius
#                    -8.302e-02                     -4.630e-01
#         wtd_std_atomic_radius                   mean_Density
#                    -2.683e-01                     -4.892e-03
#                 gmean_Density              wtd_gmean_Density
#                     1.204e-03                      2.334e-03
#               entropy_Density            wtd_entropy_Density
#                     1.299e+01                     -1.629e+01
#                 range_Density                    std_Density
#                    -1.523e-03                      5.628e-03
#               wtd_std_Density      wtd_mean_ElectronAffinity
#                    -1.245e-03                      4.527e-01
#        gmean_ElectronAffinity     wtd_gmean_ElectronAffinity
#                     1.092e-01                     -5.317e-01
#  wtd_entropy_ElectronAffinity         range_ElectronAffinity
#                    -1.926e+01                     -3.642e-01
#    wtd_range_ElectronAffinity           std_ElectronAffinity
#                    -1.178e-01                      1.141e+00
#      wtd_std_ElectronAffinity                mean_FusionHeat
#                    -4.943e-01                      1.413e+00
#           wtd_mean_FusionHeat               gmean_FusionHeat
#                    -1.631e+00                     -1.318e+00
#          wtd_gmean_FusionHeat             entropy_FusionHeat
#                     1.379e+00                     -1.870e+01
#        wtd_entropy_FusionHeat               range_FusionHeat
#                     2.400e+01                     -4.753e-01
#          wtd_range_FusionHeat             wtd_std_FusionHeat
#                     5.111e-01                      4.594e-01
#      mean_ThermalConductivity   wtd_mean_ThermalConductivity
#                    -1.302e-01                      5.435e-01
# wtd_gmean_ThermalConductivity    entropy_ThermalConductivity
#                    -3.461e-01                      1.432e+01
#     range_ThermalConductivity  wtd_range_ThermalConductivity
#                    -1.006e-01                     -2.353e-01
#       std_ThermalConductivity                  gmean_Valence
#                     3.443e-01                      5.493e+00
#             wtd_gmean_Valence                entropy_Valence
#                    -5.579e+00                      7.813e+01
#           wtd_entropy_Valence                  range_Valence
#                    -7.540e+01                      5.796e+00
#               wtd_std_Valence
#                    -1.939e+01

# %%
summary(fit_back_aic)
# Out:
# Call:
# lm(formula = critical_temp ~ number_of_elements + mean_atomic_mass +
#     wtd_mean_atomic_mass + gmean_atomic_mass + wtd_gmean_atomic_mass +
#     entropy_atomic_mass + range_atomic_mass + std_atomic_mass +
#     wtd_std_atomic_mass + mean_fie + wtd_mean_fie + gmean_fie +
#     wtd_gmean_fie + entropy_fie + wtd_entropy_fie + range_fie +
#     wtd_range_fie + std_fie + mean_atomic_radius + wtd_mean_atomic_radius +
#     wtd_gmean_atomic_radius + entropy_atomic_radius + wtd_entropy_atomic_radius +
#     range_atomic_radius + wtd_range_atomic_radius + std_atomic_radius +
#     wtd_std_atomic_radius + mean_Density + gmean_Density + wtd_gmean_Density +
#     entropy_Density + wtd_entropy_Density + range_Density + std_Density +
#     wtd_std_Density + mean_ElectronAffinity + wtd_mean_ElectronAffinity +
#     gmean_ElectronAffinity + wtd_gmean_ElectronAffinity + entropy_ElectronAffinity +
#     wtd_entropy_ElectronAffinity + range_ElectronAffinity + wtd_range_ElectronAffinity +
#     std_ElectronAffinity + wtd_std_ElectronAffinity + mean_FusionHeat +
#     wtd_mean_FusionHeat + gmean_FusionHeat + wtd_gmean_FusionHeat +
#     entropy_FusionHeat + wtd_entropy_FusionHeat + range_FusionHeat +
#     wtd_range_FusionHeat + std_FusionHeat + wtd_std_FusionHeat +
#     mean_ThermalConductivity + wtd_mean_ThermalConductivity +
#     gmean_ThermalConductivity + wtd_gmean_ThermalConductivity +
#     entropy_ThermalConductivity + range_ThermalConductivity +
#     wtd_range_ThermalConductivity + std_ThermalConductivity +
#     mean_Valence + wtd_mean_Valence + gmean_Valence + wtd_gmean_Valence +
#     entropy_Valence + wtd_entropy_Valence + range_Valence + std_Valence +
#     wtd_std_Valence, data = supercon_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -84.651  -9.401   0.618  10.975 170.452
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                   -1.991e+01  4.866e+00  -4.092 4.30e-05 ***
# number_of_elements            -3.738e+00  7.303e-01  -5.118 3.12e-07 ***
# mean_atomic_mass               8.633e-01  7.561e-02  11.418  < 2e-16 ***
# wtd_mean_atomic_mass          -9.010e-01  8.684e-02 -10.376  < 2e-16 ***
# gmean_atomic_mass             -5.268e-01  7.796e-02  -6.757 1.44e-11 ***
# wtd_gmean_atomic_mass          6.562e-01  8.862e-02   7.405 1.36e-13 ***
# entropy_atomic_mass           -3.289e+01  4.147e+00  -7.932 2.26e-15 ***
# range_atomic_mass              2.107e-01  1.643e-02  12.830  < 2e-16 ***
# std_atomic_mass               -5.344e-01  6.009e-02  -8.894  < 2e-16 ***
# wtd_std_atomic_mass            7.312e-02  5.116e-02   1.429 0.152955
# mean_fie                       1.967e-01  4.369e-02   4.501 6.79e-06 ***
# wtd_mean_fie                  -2.361e-01  3.604e-02  -6.551 5.83e-11 ***
# gmean_fie                     -1.881e-01  4.299e-02  -4.375 1.22e-05 ***
# wtd_gmean_fie                  2.552e-01  3.619e-02   7.052 1.82e-12 ***
# entropy_fie                   -1.193e+02  1.920e+01  -6.216 5.20e-10 ***
# wtd_entropy_fie                4.167e+01  4.449e+00   9.365  < 2e-16 ***
# range_fie                      6.802e-02  6.383e-03  10.655  < 2e-16 ***
# wtd_range_fie                  2.048e-02  3.252e-03   6.297 3.10e-10 ***
# std_fie                       -2.168e-01  1.617e-02 -13.406  < 2e-16 ***
# mean_atomic_radius            -3.418e-01  2.735e-02 -12.499  < 2e-16 ***
# wtd_mean_atomic_radius         3.072e+00  1.548e-01  19.846  < 2e-16 ***
# wtd_gmean_atomic_radius       -2.676e+00  1.463e-01 -18.293  < 2e-16 ***
# entropy_atomic_radius          7.988e+01  1.693e+01   4.717 2.41e-06 ***
# wtd_entropy_atomic_radius      4.803e+01  3.917e+00  12.261  < 2e-16 ***
# range_atomic_radius            1.992e-01  2.181e-02   9.134  < 2e-16 ***
# wtd_range_atomic_radius       -8.852e-02  1.257e-02  -7.044 1.93e-12 ***
# std_atomic_radius             -4.267e-01  7.068e-02  -6.038 1.59e-09 ***
# wtd_std_atomic_radius         -2.713e-01  6.211e-02  -4.368 1.26e-05 ***
# mean_Density                  -4.946e-03  3.495e-04 -14.153  < 2e-16 ***
# gmean_Density                  1.285e-03  3.525e-04   3.645 0.000268 ***
# wtd_gmean_Density              2.210e-03  2.610e-04   8.469  < 2e-16 ***
# entropy_Density                1.461e+01  3.274e+00   4.462 8.16e-06 ***
# wtd_entropy_Density           -1.776e+01  2.124e+00  -8.361  < 2e-16 ***
# range_Density                 -1.607e-03  2.146e-04  -7.488 7.26e-14 ***
# std_Density                    6.092e-03  6.520e-04   9.344  < 2e-16 ***
# wtd_std_Density               -1.528e-03  4.110e-04  -3.718 0.000201 ***
# mean_ElectronAffinity         -1.182e-01  4.556e-02  -2.595 0.009479 **
# wtd_mean_ElectronAffinity      5.315e-01  4.921e-02  10.800  < 2e-16 ***
# gmean_ElectronAffinity         1.906e-01  3.898e-02   4.890 1.02e-06 ***
# wtd_gmean_ElectronAffinity    -5.882e-01  4.266e-02 -13.789  < 2e-16 ***
# entropy_ElectronAffinity       3.917e+00  2.558e+00   1.531 0.125743
# wtd_entropy_ElectronAffinity  -2.103e+01  2.156e+00  -9.756  < 2e-16 ***
# range_ElectronAffinity        -3.660e-01  1.711e-02 -21.389  < 2e-16 ***
# wtd_range_ElectronAffinity    -1.439e-01  1.975e-02  -7.282 3.39e-13 ***
# std_ElectronAffinity           1.246e+00  5.783e-02  21.551  < 2e-16 ***
# wtd_std_ElectronAffinity      -5.506e-01  3.698e-02 -14.887  < 2e-16 ***
# mean_FusionHeat                1.686e+00  1.858e-01   9.074  < 2e-16 ***
# wtd_mean_FusionHeat           -1.870e+00  1.859e-01 -10.059  < 2e-16 ***
# gmean_FusionHeat              -1.533e+00  1.717e-01  -8.928  < 2e-16 ***
# wtd_gmean_FusionHeat           1.574e+00  1.747e-01   9.014  < 2e-16 ***
# entropy_FusionHeat            -1.882e+01  2.665e+00  -7.061 1.71e-12 ***
# wtd_entropy_FusionHeat         2.444e+01  1.857e+00  13.162  < 2e-16 ***
# range_FusionHeat              -3.857e-01  6.540e-02  -5.898 3.72e-09 ***
# wtd_range_FusionHeat           5.716e-01  6.427e-02   8.894  < 2e-16 ***
# std_FusionHeat                -4.610e-01  2.547e-01  -1.810 0.070303 .
# wtd_std_FusionHeat             6.892e-01  1.499e-01   4.599 4.26e-06 ***
# mean_ThermalConductivity      -6.602e-02  2.229e-02  -2.962 0.003061 **
# wtd_mean_ThermalConductivity   5.162e-01  2.011e-02  25.660  < 2e-16 ***
# gmean_ThermalConductivity     -6.610e-02  1.912e-02  -3.457 0.000548 ***
# wtd_gmean_ThermalConductivity -3.062e-01  1.604e-02 -19.095  < 2e-16 ***
# entropy_ThermalConductivity    1.233e+01  1.573e+00   7.839 4.76e-15 ***
# range_ThermalConductivity     -9.130e-02  1.284e-02  -7.112 1.18e-12 ***
# wtd_range_ThermalConductivity -2.365e-01  1.391e-02 -17.005  < 2e-16 ***
# std_ThermalConductivity        2.914e-01  3.553e-02   8.202 2.50e-16 ***
# mean_Valence                  -1.559e+01  5.906e+00  -2.639 0.008316 **
# wtd_mean_Valence               2.255e+01  6.948e+00   3.245 0.001175 **
# gmean_Valence                  2.005e+01  5.592e+00   3.585 0.000338 ***
# wtd_gmean_Valence             -2.718e+01  6.569e+00  -4.138 3.52e-05 ***
# entropy_Valence                7.384e+01  1.186e+01   6.228 4.81e-10 ***
# wtd_entropy_Valence           -6.799e+01  4.804e+00 -14.151  < 2e-16 ***
# range_Valence                  4.734e+00  7.269e-01   6.513 7.54e-11 ***
# std_Valence                    6.829e+00  2.383e+00   2.865 0.004172 **
# wtd_std_Valence               -2.505e+01  1.847e+00 -13.566  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 17.59 on 21190 degrees of freedom
# Multiple R-squared:  0.7372,	Adjusted R-squared:  0.7363
# F-statistic: 825.4 on 72 and 21190 DF,  p-value: < 2.2e-16

# %%
summary(fit_back_bic)
# Out:
# Call:
# lm(formula = critical_temp ~ number_of_elements + mean_atomic_mass +
#     wtd_mean_atomic_mass + gmean_atomic_mass + wtd_gmean_atomic_mass +
#     entropy_atomic_mass + range_atomic_mass + std_atomic_mass +
#     mean_fie + wtd_mean_fie + gmean_fie + wtd_gmean_fie + entropy_fie +
#     wtd_entropy_fie + range_fie + wtd_range_fie + std_fie + mean_atomic_radius +
#     wtd_mean_atomic_radius + wtd_gmean_atomic_radius + entropy_atomic_radius +
#     wtd_entropy_atomic_radius + range_atomic_radius + wtd_range_atomic_radius +
#     std_atomic_radius + wtd_std_atomic_radius + mean_Density +
#     gmean_Density + wtd_gmean_Density + entropy_Density + wtd_entropy_Density +
#     range_Density + std_Density + wtd_std_Density + wtd_mean_ElectronAffinity +
#     gmean_ElectronAffinity + wtd_gmean_ElectronAffinity + wtd_entropy_ElectronAffinity +
#     range_ElectronAffinity + wtd_range_ElectronAffinity + std_ElectronAffinity +
#     wtd_std_ElectronAffinity + mean_FusionHeat + wtd_mean_FusionHeat +
#     gmean_FusionHeat + wtd_gmean_FusionHeat + entropy_FusionHeat +
#     wtd_entropy_FusionHeat + range_FusionHeat + wtd_range_FusionHeat +
#     wtd_std_FusionHeat + mean_ThermalConductivity + wtd_mean_ThermalConductivity +
#     wtd_gmean_ThermalConductivity + entropy_ThermalConductivity +
#     range_ThermalConductivity + wtd_range_ThermalConductivity +
#     std_ThermalConductivity + gmean_Valence + wtd_gmean_Valence +
#     entropy_Valence + wtd_entropy_Valence + range_Valence + wtd_std_Valence,
#     data = supercon_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -83.947  -9.317   0.574  10.915 170.776
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                   -1.861e+01  4.796e+00  -3.880 0.000105 ***
# number_of_elements            -3.560e+00  7.167e-01  -4.967 6.84e-07 ***
# mean_atomic_mass               7.717e-01  5.928e-02  13.018  < 2e-16 ***
# wtd_mean_atomic_mass          -7.805e-01  5.121e-02 -15.241  < 2e-16 ***
# gmean_atomic_mass             -4.370e-01  6.284e-02  -6.954 3.66e-12 ***
# wtd_gmean_atomic_mass          5.296e-01  5.476e-02   9.672  < 2e-16 ***
# entropy_atomic_mass           -3.365e+01  4.051e+00  -8.307  < 2e-16 ***
# range_atomic_mass              2.077e-01  1.613e-02  12.873  < 2e-16 ***
# std_atomic_mass               -4.709e-01  4.379e-02 -10.752  < 2e-16 ***
# mean_fie                       1.655e-01  4.264e-02   3.882 0.000104 ***
# wtd_mean_fie                  -2.170e-01  3.470e-02  -6.252 4.13e-10 ***
# gmean_fie                     -1.630e-01  4.214e-02  -3.867 0.000111 ***
# wtd_gmean_fie                  2.400e-01  3.464e-02   6.928 4.40e-12 ***
# entropy_fie                   -1.037e+02  1.789e+01  -5.799 6.78e-09 ***
# wtd_entropy_fie                4.357e+01  3.976e+00  10.959  < 2e-16 ***
# range_fie                      6.865e-02  6.246e-03  10.990  < 2e-16 ***
# wtd_range_fie                  1.990e-02  3.124e-03   6.372 1.91e-10 ***
# std_fie                       -2.104e-01  1.591e-02 -13.221  < 2e-16 ***
# mean_atomic_radius            -3.499e-01  2.682e-02 -13.047  < 2e-16 ***
# wtd_mean_atomic_radius         3.055e+00  1.513e-01  20.187  < 2e-16 ***
# wtd_gmean_atomic_radius       -2.653e+00  1.432e-01 -18.533  < 2e-16 ***
# entropy_atomic_radius          6.245e+01  1.632e+01   3.826 0.000131 ***
# wtd_entropy_atomic_radius      5.158e+01  3.633e+00  14.199  < 2e-16 ***
# range_atomic_radius            2.073e-01  2.133e-02   9.718  < 2e-16 ***
# wtd_range_atomic_radius       -8.302e-02  1.214e-02  -6.841 8.10e-12 ***
# std_atomic_radius             -4.630e-01  7.014e-02  -6.600 4.21e-11 ***
# wtd_std_atomic_radius         -2.683e-01  6.173e-02  -4.346 1.39e-05 ***
# mean_Density                  -4.892e-03  3.459e-04 -14.145  < 2e-16 ***
# gmean_Density                  1.204e-03  3.496e-04   3.444 0.000574 ***
# wtd_gmean_Density              2.334e-03  2.573e-04   9.070  < 2e-16 ***
# entropy_Density                1.299e+01  3.132e+00   4.146 3.39e-05 ***
# wtd_entropy_Density           -1.629e+01  2.023e+00  -8.051 8.67e-16 ***
# range_Density                 -1.522e-03  2.096e-04  -7.265 3.87e-13 ***
# std_Density                    5.628e-03  6.406e-04   8.786  < 2e-16 ***
# wtd_std_Density               -1.245e-03  3.816e-04  -3.262 0.001107 **
# wtd_mean_ElectronAffinity      4.527e-01  3.355e-02  13.492  < 2e-16 ***
# gmean_ElectronAffinity         1.092e-01  1.418e-02   7.703 1.39e-14 ***
# wtd_gmean_ElectronAffinity    -5.317e-01  3.265e-02 -16.282  < 2e-16 ***
# wtd_entropy_ElectronAffinity  -1.926e+01  1.768e+00 -10.895  < 2e-16 ***
# range_ElectronAffinity        -3.642e-01  1.624e-02 -22.427  < 2e-16 ***
# wtd_range_ElectronAffinity    -1.178e-01  1.726e-02  -6.824 9.07e-12 ***
# std_ElectronAffinity           1.141e+00  4.609e-02  24.755  < 2e-16 ***
# wtd_std_ElectronAffinity      -4.943e-01  3.129e-02 -15.795  < 2e-16 ***
# mean_FusionHeat                1.413e+00  1.371e-01  10.308  < 2e-16 ***
# wtd_mean_FusionHeat           -1.631e+00  1.536e-01 -10.618  < 2e-16 ***
# gmean_FusionHeat              -1.318e+00  1.358e-01  -9.707  < 2e-16 ***
# wtd_gmean_FusionHeat           1.379e+00  1.518e-01   9.081  < 2e-16 ***
# entropy_FusionHeat            -1.870e+01  2.479e+00  -7.540 4.88e-14 ***
# wtd_entropy_FusionHeat         2.400e+01  1.715e+00  13.995  < 2e-16 ***
# range_FusionHeat              -4.753e-01  3.920e-02 -12.127  < 2e-16 ***
# wtd_range_FusionHeat           5.111e-01  5.575e-02   9.168  < 2e-16 ***
# wtd_std_FusionHeat             4.594e-01  1.069e-01   4.297 1.74e-05 ***
# mean_ThermalConductivity      -1.302e-01  1.508e-02  -8.630  < 2e-16 ***
# wtd_mean_ThermalConductivity   5.435e-01  1.935e-02  28.087  < 2e-16 ***
# wtd_gmean_ThermalConductivity -3.461e-01  1.243e-02 -27.848  < 2e-16 ***
# entropy_ThermalConductivity    1.432e+01  1.421e+00  10.079  < 2e-16 ***
# range_ThermalConductivity     -1.006e-01  1.257e-02  -8.008 1.23e-15 ***
# wtd_range_ThermalConductivity -2.353e-01  1.368e-02 -17.202  < 2e-16 ***
# std_ThermalConductivity        3.443e-01  3.251e-02  10.591  < 2e-16 ***
# gmean_Valence                  5.493e+00  7.646e-01   7.184 7.01e-13 ***
# wtd_gmean_Valence             -5.579e+00  7.064e-01  -7.897 3.00e-15 ***
# entropy_Valence                7.813e+01  9.009e+00   8.672  < 2e-16 ***
# wtd_entropy_Valence           -7.540e+01  3.775e+00 -19.975  < 2e-16 ***
# range_Valence                  5.796e+00  4.037e-01  14.357  < 2e-16 ***
# wtd_std_Valence               -1.939e+01  8.640e-01 -22.444  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 17.6 on 21198 degrees of freedom
# Multiple R-squared:  0.7367,	Adjusted R-squared:  0.7359
# F-statistic: 926.8 on 64 and 21198 DF,  p-value: < 2.2e-16
